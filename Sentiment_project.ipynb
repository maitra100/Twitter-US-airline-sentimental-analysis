# %%
import pandas as pd
df=pd.read_csv('Tweets.csv')
df.iloc[5,10]
# Out:
# "@VirginAmerica seriously would pay $30 a flight for seats that didn't have this playing.\nit's really the only bad thing about flying VA"

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('state_union')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('movie_reviews')
nltk.download('punkt')
nltk.download('maxent_treebank_pos_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package state_union to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package state_union is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package maxent_treebank_pos_tagger to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_treebank_pos_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk import sent_tokenize,word_tokenize
from nltk.corpus import stopwords
import string
from nltk.stem import WordNetLemmatizer

# %%
words=[(df.iloc[i,10],df.iloc[i,1]) for i in range(14640)]

# %%
def tokenize(word):
    token_words=word_tokenize(word)
    return token_words

new_words=[(tokenize(word),category) for word,category in words]

# %%
stop_words=stopwords.words('english')
punct=list(string.punctuation)
stop_words+=punct

# %%
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from nltk.corpus import state_union
lemmatizer=WordNetLemmatizer()

from nltk.corpus import wordnet
def get_simple_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

def clean_review(words):
    output=[]
    for w in words:
        if(w.lower() not in stop_words):
            pos=pos_tag([w])
            clean_word=lemmatizer.lemmatize(w,pos=get_simple_pos(pos[0][1]))
            output.append(clean_word)
    return output

# %%
documents=[(clean_review(word),category) for word,category in new_words]

# %%
documents[0]
# Out:
# (['VirginAmerica', 'dhepburn', 'say'], 'neutral')

# %%
training_data=documents[0:10000]
testing_data=documents[10000:]

# %%
all_words=[]
for doc in training_data:
    all_words+=doc[0]
    
freq=nltk.FreqDist(all_words)
common=freq.most_common(10000)
features=[i[0] for i in common]
features[0:10]
# Out:
# ['united',
#  'flight',
#  'SouthwestAir',
#  'JetBlue',
#  "n't",
#  'get',
#  "'s",
#  'USAirways',
#  'http',
#  'hour']

# %%
def get_dict(words):
    new_dict={}
    for w in features:
        new_dict[w]=w in words
    return new_dict

# %%
training_check=[(get_dict(words),category) for words,category in training_data]
testing_check=[(get_dict(words),category) for words,category in testing_data]

# %%
testing_check[0]
# Out:
# ({'united': False,
#   'flight': True,
#   'SouthwestAir': False,
#   'JetBlue': False,
#   "n't": False,
#   'get': True,
#   "'s": False,
#   'USAirways': True,
#   'http': False,
#   'hour': False,
#   'time': False,
#   'service': False,
#   'Cancelled': True,
#   'customer': False,
#   '...': False,
#   'bag': False,
#   'u': False,
#   'VirginAmerica': False,
#   'fly': False,
#   'Flight': True,
#   'go': False,
#   'help': False,
#   "'m": False,
#   'plane': False,
#   'amp': False,
#   'make': False,
#   'wait': True,
#   'would': False,
#   'Thanks': False,
#   'need': False,
#   '2': False,
#   'thanks': False,
#   'delayed': False,
#   'one': False,
#   'airline': False,
#   'seat': True,
#   'take': False,
#   'hold': False,
#   'day': True,
#   'say': False,
#   'gate': False,
#   'United': False,
#   'call': False,
#   'delay': False,
#   "''": False,
#   'back': False,
#   'try': False,
#   '``': False,
#   'still': False,
#   'like': False,
#   'know': False,
#   'Late': True,
#   "'ve": False,
#   'guy': False,
#   'today': False,
#   'change': False,
#   'ca': False,
#   'work': False,
#   'ticket': False,
#   'Flightled': True,
#   'give': False,
#   'bad': False,
#   'please': False,
#   'Thank': False,
#   'miss': False,
#   'way': False,
#   'phone': False,
#   'minute': False,
#   'book': False,
#   '3': False,
#   'lose': False,
#   'want': False,
#   'check': False,
#   'airport': False,
#   'travel': False,
#   'agent': False,
#   'see': False,
#   "'re": False,
#   'well': False,
#   'last': False,
#   'great': False,
#   'thank': False,
#   'issue': False,
#   'min': False,
#   'could': False,
#   "'ll": False,
#   'DM': False,
#   'email': False,
#   'even': False,
#   'use': False,
#   'people': False,
#   'love': False,
#   'never': False,
#   'trip': False,
#   'good': False,
#   'hr': False,
#   'home': False,
#   'tomorrow': False,
#   '”': False,
#   'luggage': False,
#   '4': False,
#   'look': False,
#   'first': False,
#   'really': False,
#   '“': False,
#   'new': False,
#   'crew': False,
#   '..': False,
#   'passenger': False,
#   'baggage': False,
#   'let': False,
#   'much': False,
#   'fleet': False,
#   'experience': False,
#   'fleek': False,
#   'number': False,
#   'sit': False,
#   'weather': False,
#   'come': False,
#   'due': False,
#   'right': False,
#   'next': False,
#   'told': True,
#   'someone': False,
#   'boarding': False,
#   'another': False,
#   'follow': False,
#   'ever': False,
#   'sent': False,
#   'response': False,
#   'two': False,
#   'week': False,
#   '1': True,
#   'tell': False,
#   'board': False,
#   'best': False,
#   'Flighted': False,
#   'update': False,
#   'show': True,
#   'find': False,
#   'land': False,
#   'staff': False,
#   'Please': False,
#   'left': False,
#   'leave': False,
#   'connection': False,
#   'sure': False,
#   'yes': False,
#   'problem': False,
#   'long': False,
#   'think': False,
#   'refund': False,
#   'year': False,
#   'reservation': False,
#   'JFK': False,
#   'care': False,
#   'ask': False,
#   'pay': False,
#   "'d": False,
#   'answer': False,
#   'morning': False,
#   'already': False,
#   'AmericanAir': False,
#   'line': False,
#   'pilot': False,
#   'online': False,
#   'website': False,
#   'Flightr': False,
#   '5': False,
#   'free': False,
#   'tonight': False,
#   'attendant': False,
#   'Booking': False,
#   'arrive': False,
#   'Problems': False,
#   'point': False,
#   'info': False,
#   'charge': False,
#   'start': False,
#   'keep': False,
#   'put': False,
#   'night': False,
#   'ago': False,
#   'yet': False,
#   '....': False,
#   'jetblue': False,
#   'mile': False,
#   '’': False,
#   'system': False,
#   'credit': False,
#   'hotel': False,
#   'since': True,
#   'checked': False,
#   'stuck': False,
#   'wifi': False,
#   'add': False,
#   'thing': False,
#   'happen': False,
#   'RT': False,
#   'upgrade': False,
#   'appreciate': False,
#   'wo': False,
#   'send': False,
#   'SFO': False,
#   'business': False,
#   'tweet': False,
#   'claim': False,
#   'gt': False,
#   'receive': False,
#   'voucher': False,
#   'employee': False,
#   'name': False,
#   'fix': False,
#   'early': False,
#   'nothing': False,
#   'do': False,
#   'DestinationDragons': False,
#   'option': False,
#   'open': False,
#   'available': False,
#   'offer': False,
#   'Denver': False,
#   'via': False,
#   'US': False,
#   '10': False,
#   'awesome': False,
#   'able': False,
#   'connect': False,
#   'nice': False,
#   'anything': False,
#   'fail': False,
#   'amaze': False,
#   'schedule': False,
#   'direct': False,
#   'frustrate': False,
#   'contact': False,
#   'chance': False,
#   'person': False,
#   'every': False,
#   'class': False,
#   'departure': False,
#   'hope': False,
#   'app': False,
#   'return': False,
#   'always': False,
#   'pas': False,
#   'rude': False,
#   '1st': False,
#   'talk': False,
#   '20': False,
#   '30': False,
#   'status': False,
#   'deal': False,
#   'LAX': False,
#   'finally': False,
#   'site': False,
#   '6': False,
#   'fee': False,
#   'rep': False,
#   'kid': False,
#   'rebook': False,
#   'Boston': False,
#   'team': False,
#   'Vegas': False,
#   'helpful': False,
#   'flt': False,
#   'friend': False,
#   'earlier': False,
#   'disappointed': False,
#   'many': False,
#   'w/': False,
#   'seem': False,
#   'understand': False,
#   'reply': False,
#   'family': False,
#   'also': False,
#   'ground': False,
#   'ORD': False,
#   'stop': False,
#   'EWR': False,
#   'though': False,
#   'paid': False,
#   'suck': False,
#   'mean': False,
#   'air': False,
#   'account': False,
#   'Help': False,
#   'move': False,
#   'Southwest': False,
#   'instead': False,
#   'without': False,
#   'Chicago': False,
#   'month': False,
#   'reason': False,
#   'different': False,
#   'speak': False,
#   'link': False,
#   'question': False,
#   'something': False,
#   'old': False,
#   'yesterday': False,
#   'policy': False,
#   'company': False,
#   'almost': False,
#   'extra': False,
#   'money': False,
#   '8': False,
#   'job': False,
#   'message': False,
#   'UA': False,
#   'away': False,
#   'least': False,
#   'card': False,
#   'snow': False,
#   'full': False,
#   'actually': False,
#   'request': False,
#   'Newark': False,
#   'Great': False,
#   'suppose': False,
#   'confirm': False,
#   'Still': False,
#   'vacation': False,
#   'rebooked': False,
#   'lot': False,
#   'member': False,
#   'wife': False,
#   'anyone': False,
#   'San': False,
#   'confirmation': False,
#   'expect': False,
#   'BOS': False,
#   'strand': False,
#   'plan': False,
#   'treat': False,
#   'terrible': False,
#   'cause': False,
#   'IAD': False,
#   '--': False,
#   'Ca': False,
#   'happy': False,
#   'ok': False,
#   'Houston': False,
#   'found': False,
#   'far': False,
#   'hung': False,
#   'sorry': False,
#   'respond': False,
#   'enough': False,
#   'little': False,
#   'mechanical': False,
#   'destination': False,
#   'row': False,
#   'room': False,
#   'switch': False,
#   'Delta': False,
#   'soon': False,
#   'ur': False,
#   'less': False,
#   'CEO': False,
#   'Yes': False,
#   'allow': False,
#   'SWA': False,
#   'fare': False,
#   'Need': False,
#   'horrible': False,
#   'run': False,
#   'broken': False,
#   'Thx': False,
#   'car': False,
#   'hear': False,
#   'idea': False,
#   'ridiculous': False,
#   'southwestair': False,
#   'U': False,
#   'feel': False,
#   'cool': False,
#   'around': False,
#   'Hi': False,
#   'PHL': True,
#   'provide': False,
#   'might': False,
#   'wrong': False,
#   'cost': False,
#   'everyone': False,
#   'deliver': False,
#   'Imaginedragons': False,
#   'Really': False,
#   'NYC': False,
#   'Dallas': False,
#   'DCA': False,
#   'past': False,
#   'half': False,
#   '15': True,
#   '7': False,
#   'bc': False,
#   'usairways': False,
#   'New': False,
#   '40': False,
#   'watch': False,
#   'bring': False,
#   'longer': False,
#   'w': False,
#   'price': False,
#   'end': False,
#   'error': False,
#   'reschedule': False,
#   'quick': False,
#   'forward': False,
#   'carry': False,
#   'poor': False,
#   'complaint': False,
#   'apology': False,
#   'place': False,
#   'sleep': False,
#   '45': False,
#   'plus': False,
#   'share': False,
#   'Love': False,
#   'route': False,
#   'terminal': False,
#   'form': False,
#   'FLL': False,
#   'big': False,
#   'second': False,
#   'heard': False,
#   'three': False,
#   'food': False,
#   'possible': False,
#   'computer': False,
#   'address': False,
#   'drive': False,
#   '2nd': False,
#   'together': False,
#   'hard': False,
#   '100': False,
#   '50': False,
#   'na': False,
#   'thought': False,
#   'list': False,
#   'twice': False,
#   'SW': False,
#   'city': False,
#   'drop': False,
#   'easy': False,
#   'may': False,
#   'loyal': False,
#   'group': True,
#   'case': False,
#   'IAH': False,
#   'guess': False,
#   'else': False,
#   'UnitedAirlines': False,
#   'leg': False,
#   'Airways': False,
#   'lt': False,
#   'DC': False,
#   'waste': False,
#   'stay': False,
#   'handle': False,
#   'life': False,
#   'Twitter': False,
#   '200': False,
#   'close': False,
#   'desk': False,
#   'head': False,
#   'believe': False,
#   'real': False,
#   'information': False,
#   'maintenance': False,
#   'load': False,
#   'assistance': False,
#   'Monday': False,
#   '1/2': False,
#   'file': False,
#   'cust': False,
#   'Airlines': False,
#   'international': False,
#   'Customer': False,
#   'BWI': False,
#   'date': False,
#   'runway': False,
#   'seriously': False,
#   'flyer': False,
#   'thx': False,
#   'fine': False,
#   'traveler': False,
#   'depart': False,
#   'standby': True,
#   'hop': False,
#   'resolve': False,
#   'explain': False,
#   '25': False,
#   'jet': False,
#   'figure': False,
#   'screw': False,
#   'oh': False,
#   'flew': False,
#   'everything': False,
#   'process': False,
#   'Good': False,
#   'empty': False,
#   'child': False,
#   'Never': False,
#   'set': False,
#   'Would': False,
#   'turn': False,
#   'DEN': False,
#   'pick': False,
#   'Maybe': False,
#   'Nashville': False,
#   '24': False,
#   'Atlanta': False,
#   'purchase': False,
#   'force': False,
#   'southwest': False,
#   'tarmac': False,
#   'rather': False,
#   'reach': False,
#   'spent': False,
#   'hate': False,
#   'pretty': False,
#   'MCO': False,
#   'birthday': False,
#   'Gate': False,
#   '9': False,
#   'promise': False,
#   'fill': False,
#   'Airport': False,
#   'detail': False,
#   'weekend': False,
#   'note': False,
#   'reFlight': False,
#   'Sunday': False,
#   'companion': False,
#   'flown': False,
#   '2015': False,
#   'buy': False,
#   'Austin': False,
#   'refuse': False,
#   'save': False,
#   'Looking': False,
#   "y'all": False,
#   'future': False,
#   'sign': False,
#   'clothes': False,
#   'awful': False,
#   'Orlando': False,
#   'Wall': False,
#   'rock': False,
#   'LA': False,
#   'page': False,
#   'correct': False,
#   'LGA': False,
#   'Got': False,
#   'Worst': False,
#   'fun': False,
#   'entire': False,
#   'safety': False,
#   'currently': False,
#   'yr': False,
#   'submit': False,
#   'part': False,
#   'Flighting': False,
#   'word': False,
#   'Delayed': False,
#   'transfer': False,
#   'supervisor': False,
#   'thru': False,
#   'aircraft': False,
#   'pass': False,
#   'live': False,
#   'Well': False,
#   'cross': False,
#   'support': False,
#   'win': False,
#   'bought': False,
#   'Another': False,
#   'TSA': False,
#   'checkin': False,
#   'high': False,
#   'report': False,
#   'First': False,
#   'lack': False,
#   'maybe': False,
#   'daughter': False,
#   'American': False,
#   'read': False,
#   'mine': False,
#   'fact': False,
#   'fuck': False,
#   'attitude': False,
#   'disconnect': False,
#   'PHX': False,
#   'mess': False,
#   'hi': False,
#   'post': False,
#   'award': False,
#   'happens': False,
#   'layover': False,
#   'super': False,
#   'One': False,
#   'wonder': False,
#   'ready': False,
#   'round': False,
#   'joke': False,
#   'Also': False,
#   'learn': False,
#   'whole': False,
#   'storm': False,
#   'compensation': False,
#   'okay': False,
#   'counter': False,
#   'ruin': False,
#   'lie': False,
#   'sense': False,
#   'ATL': True,
#   'fault': False,
#   'blue': False,
#   'Virgin': False,
#   'worry': False,
#   'trouble': False,
#   'Friday': False,
#   'Flightlation': False,
#   'area': False,
#   'cabin': False,
#   'space': False,
#   'course': False,
#   'lol': False,
#   'mom': False,
#   'communication': False,
#   'Air': False,
#   'Service': False,
#   'kind': False,
#   'LAS': False,
#   'apply': False,
#   'middle': False,
#   'wish': False,
#   'track': False,
#   'yall': False,
#   'human': False,
#   'TV': False,
#   'jfk': False,
#   'must': False,
#   'drink': False,
#   'access': False,
#   'gon': False,
#   'Trying': False,
#   'window': False,
#   'small': False,
#   'rate': False,
#   'pls': False,
#   'tix': False,
#   'overhead': False,
#   'son': False,
#   'overnight': False,
#   '11': False,
#   'arrival': False,
#   'Tarmac': False,
#   'front': False,
#   'counting': False,
#   'country': False,
#   'cold': False,
#   'beyond': False,
#   'Hey': False,
#   'Let': False,
#   'world': False,
#   'include': False,
#   'notice': False,
#   'afternoon': False,
#   'order': False,
#   'despite': False,
#   'several': False,
#   'glad': False,
#   '3rd': False,
#   '12': False,
#   'luck': False,
#   'Oh': False,
#   'wonderful': False,
#   'upset': False,
#   'top': False,
#   'blame': False,
#   'CLT': False,
#   'door': False,
#   'catch': False,
#   'sat': False,
#   'cover': False,
#   'dont': False,
#   'hey': False,
#   'BNA': False,
#   'virginamerica': False,
#   'either': False,
#   'mobile': False,
#   'customerservice': False,
#   'cant': False,
#   'unacceptable': False,
#   'assist': False,
#   'item': False,
#   'continue': False,
#   'March': False,
#   'inconvenience': False,
#   'Get': False,
#   'low': False,
#   'announce': False,
#   'meeting': False,
#   'ppl': False,
#   'stand': False,
#   'enjoy': False,
#   'probably': False,
#   'matter': False,
#   'original': False,
#   'write': False,
#   'situation': False,
#   'multiple': False,
#   'priority': False,
#   'Finally': False,
#   '1.5': False,
#   'water': False,
#   'entertainment': False,
#   'excite': False,
#   'ride': False,
#   'video': False,
#   'Pls': False,
#   'husband': False,
#   'sell': False,
#   'short': False,
#   'anymore': False,
#   'concern': False,
#   'lounge': False,
#   'Unacceptable': False,
#   'offering': False,
#   'tire': False,
#   'consider': False,
#   'airplane': False,
#   'Jet': False,
#   'record': False,
#   '2.5': False,
#   'Street': False,
#   'enter': False,
#   'takeoff': False,
#   'step': False,
#   'code': False,
#   'b/c': False,
#   'completely': False,
#   'nonstop': False,
#   'absolutely': False,
#   'receipt': False,
#   'Could': False,
#   'pull': False,
#   'favorite': False,
#   'Stuck': False,
#   'shit': False,
#   'man': False,
#   'saw': False,
#   'domestic': False,
#   'honor': False,
#   'held': False,
#   'feedback': False,
#   'pm': False,
#   'tag': False,
#   'failure': False,
#   'office': False,
#   'state': False,
#   'listen': False,
#   'RDU': False,
#   'baby': False,
#   'hang': False,
#   'Flightlations': False,
#   'explanation': False,
#   'true': False,
#   'May': False,
#   'non': False,
#   'current': False,
#   'Feb': False,
#   'inflight': False,
#   'Flying': False,
#   'begin': False,
#   'spend': False,
#   'twitter': False,
#   'check-in': False,
#   '800': False,
#   'Awesome': False,
#   'coffee': False,
#   'frequent': False,
#   'behind': False,
#   'WTF': False,
#   'mileage': False,
#   'slow': False,
#   'partner': False,
#   'ASAP': False,
#   'Hope': False,
#   'avgeek': False,
#   'club': False,
#   'folk': False,
#   'knew': False,
#   'excuse': False,
#   'worth': False,
#   '1K': False,
#   'lady': False,
#   'n': False,
#   'AA': False,
#   'Hopefully': False,
#   'onboard': False,
#   'meal': False,
#   'huge': False,
#   'fan': False,
#   'busy': False,
#   'relation': False,
#   'Blue': False,
#   'match': False,
#   'program': False,
#   'Club': False,
#   'wow': False,
#   '😊': False,
#   'Sorry': False,
#   'Im': False,
#   'Saturday': False,
#   'friendly': False,
#   'totally': False,
#   'Every': False,
#   'Terrible': False,
#   'expire': False,
#   'LUV': False,
#   'notification': False,
#   'stuff': False,
#   'apparently': False,
#   'NY': False,
#   'become': False,
#   'Next': False,
#   'screen': False,
#   'earn': False,
#   'spoke': False,
#   'Mexico': False,
#   'battle': False,
#   'Philly': False,
#   'dm': False,
#   'security': False,
#   'touch': False,
#   'rule': False,
#   'Even': False,
#   'announcement': False,
#   'equipment': False,
#   'winter': False,
#   'extremely': False,
#   'nope': False,
#   'walk': False,
#   'clear': False,
#   'WORST': False,
#   'power': False,
#   'notify': False,
#   'exit': False,
#   'party': False,
#   'play': False,
#   'sky': False,
#   'Nice': False,
#   'Best': False,
#   'hand': False,
#   'hire': False,
#   'welcome': False,
#   'special': False,
#   'definitely': False,
#   'sad': False,
#   'bit': False,
#   'arrives': False,
#   'luv': False,
#   'Flt': False,
#   'resolution': False,
#   'view': False,
#   'rental': False,
#   'Diego': False,
#   'excellent': False,
#   'nightmare': False,
#   'WiFi': False,
#   'Flights': False,
#   'actual': False,
#   'Miami': False,
#   'total': False,
#   'mistake': False,
#   'delta': False,
#   'shot': False,
#   'deny': False,
#   'NEVER': False,
#   'compensate': False,
#   'im': False,
#   'hopefully': False,
#   'snack': False,
#   'haha': False,
#   'appease': False,
#   'face': False,
#   'carrier': False,
#   'news': False,
#   'DAL': False,
#   'anyway': False,
#   'disappoint': False,
#   'bin': False,
#   'text': False,
#   'kept': False,
#   'Keep': False,
#   'along': False,
#   'sound': False,
#   'count': False,
#   'sort': False,
#   'itinerary': False,
#   'suitcase': False,
#   'tv': False,
#   'See': False,
#   'others': False,
#   'complete': False,
#   'cut': False,
#   'break': False,
#   'control': False,
#   'bother': False,
#   'attempt': False,
#   'Everyone': False,
#   'Flightd': False,
#   'appear': False,
#   'usually': False,
#   'delivery': False,
#   'unfortunately': False,
#   'major': False,
#   'THANK': False,
#   'single': False,
#   'ID': False,
#   '1hr': False,
#   'woman': False,
#   'b': False,
#   'crazy': False,
#   'Seriously': False,
#   'clean': False,
#   'log': False,
#   'bumped': False,
#   'sister': False,
#   'zero': False,
#   'sale': False,
#   'Makes': False,
#   'yeah': False,
#   'Journal': False,
#   'commercial': False,
#   'America': False,
#   'HELP': False,
#   'prefer': False,
#   'Hawaii': False,
#   'mind': False,
#   'Tried': False,
#   'lax': False,
#   'four': False,
#   'music': False,
#   'sfo': False,
#   'damage': False,
#   'DFW': False,
#   'web': False,
#   'reimburse': False,
#   'met': False,
#   'mention': False,
#   '90': False,
#   'girl': False,
#   'event': False,
#   'light': False,
#   'picked': False,
#   '😉': False,
#   'dollar': False,
#   'accept': False,
#   'raise': False,
#   'accommodate': False,
#   'prior': False,
#   'anywhere': False,
#   'MileagePlus': False,
#   'remember': False,
#   'comment': False,
#   'Going': False,
#   'unable': False,
#   'literally': False,
#   'inside': False,
#   'effort': False,
#   'final': False,
#   'prompt': False,
#   'choose': False,
#   'difference': False,
#   'Florida': False,
#   'redeem': False,
#   'badservice': False,
#   'usairwaysfail': False,
#   'visit': False,
#   'ice': False,
#   'except': False,
#   'social': False,
#   'discount': False,
#   '👍': False,
#   'Hello': False,
#   'department': False,
#   'specific': False,
#   'die': False,
#   'alert': False,
#   'JBLU': False,
#   'select': False,
#   'Time': False,
#   'game': False,
#   'Looks': False,
#   'absolute': False,
#   'Oscars': False,
#   ...},
#  'negative')

# %%
from nltk import NaiveBayesClassifier
classifier=NaiveBayesClassifier.train(training_check)

# %%
nltk.classify.accuracy(classifier,testing_check)
# Out:
# 0.8161637931034482

# %%
classifier.show_most_informative_features(20)
# Out:
# Most Informative Features
#                    Great = True           positi : neutra =     37.2 : 1.0
#                     rock = True           positi : negati =     28.3 : 1.0
#                 favorite = True           positi : negati =     28.3 : 1.0
#                     Wall = True           neutra : negati =     24.4 : 1.0
#                  helpful = True           positi : neutra =     22.3 : 1.0
#               Appreciate = True           positi : negati =     22.0 : 1.0
#                    kudos = True           positi : negati =     22.0 : 1.0
#                    Kudos = True           positi : negati =     19.9 : 1.0
#                  Awesome = True           positi : negati =     19.5 : 1.0
#                  awesome = True           positi : negati =     19.3 : 1.0
#                       hr = True           negati : positi =     18.9 : 1.0
#                 discount = True           neutra : negati =     18.3 : 1.0
#                excellent = True           positi : negati =     18.2 : 1.0
#                    thank = True           positi : negati =     18.0 : 1.0
#                      fix = True           negati : neutra =     18.0 : 1.0
#                    Thank = True           positi : negati =     17.7 : 1.0
#                   Street = True           neutra : negati =     16.7 : 1.0
#                       wo = True           negati : positi =     16.5 : 1.0
#                     suck = True           negati : neutra =     15.8 : 1.0
#                     Wish = True           positi : negati =     15.7 : 1.0
