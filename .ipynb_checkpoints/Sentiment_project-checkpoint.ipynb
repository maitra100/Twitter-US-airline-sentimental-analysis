# %%
import pandas as pd
df=pd.read_csv('Tweets.csv')
df.iloc[5,10]
# Out:
# "@VirginAmerica seriously would pay $30 a flight for seats that didn't have this playing.\nit's really the only bad thing about flying VA"

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('state_union')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('movie_reviews')
nltk.download('punkt')
nltk.download('maxent_treebank_pos_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package state_union to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package state_union is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package maxent_treebank_pos_tagger to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_treebank_pos_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk import sent_tokenize,word_tokenize
from nltk.corpus import stopwords
import string
from nltk.stem import WordNetLemmatizer

# %%
words=[(df.iloc[i,10],df.iloc[i,1]) for i in range(14640)]
words[0:5]
# Out:
# [('@VirginAmerica What @dhepburn said.', 'neutral'),
#  ("@VirginAmerica plus you've added commercials to the experience... tacky.",
#   'positive'),
#  ("@VirginAmerica I didn't today... Must mean I need to take another trip!",
#   'neutral'),
#  ('@VirginAmerica it\'s really aggressive to blast obnoxious "entertainment" in your guests\' faces &amp; they have little recourse',
#   'negative'),
#  ("@VirginAmerica and it's a really big bad thing about it", 'negative')]

# %%
def tokenize(word):
    token_words=word_tokenize(word)
    return token_words

new_words=[(tokenize(word),category) for word,category in words]
print(new_words[0:5])
# Out:
# [(['@', 'VirginAmerica', 'What', '@', 'dhepburn', 'said', '.'], 'neutral'), (['@', 'VirginAmerica', 'plus', 'you', "'ve", 'added', 'commercials', 'to', 'the', 'experience', '...', 'tacky', '.'], 'positive'), (['@', 'VirginAmerica', 'I', 'did', "n't", 'today', '...', 'Must', 'mean', 'I', 'need', 'to', 'take', 'another', 'trip', '!'], 'neutral'), (['@', 'VirginAmerica', 'it', "'s", 'really', 'aggressive', 'to', 'blast', 'obnoxious', '``', 'entertainment', "''", 'in', 'your', 'guests', "'", 'faces', '&', 'amp', ';', 'they', 'have', 'little', 'recourse'], 'negative'), (['@', 'VirginAmerica', 'and', 'it', "'s", 'a', 'really', 'big', 'bad', 'thing', 'about', 'it'], 'negative')]

# %%
stop_words=stopwords.words('english')
punct=list(string.punctuation)
stop_words+=punct
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  '!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~']

# %%
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from nltk.corpus import state_union
lemmatizer=WordNetLemmatizer()

from nltk.corpus import wordnet
def get_simple_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

def clean_review(words):
    output=[]
    for w in words:
        if(w.lower() not in stop_words):
            pos=pos_tag([w])
            clean_word=lemmatizer.lemmatize(w,pos=get_simple_pos(pos[0][1]))
            output.append(clean_word)
    return output

# %%
documents=[(clean_review(word),category) for word,category in new_words]
# Out:
# [(['VirginAmerica', 'dhepburn', 'say'], 'neutral'),
#  (['VirginAmerica',
#    'plus',
#    "'ve",
#    'add',
#    'commercial',
#    'experience',
#    '...',
#    'tacky'],
#   'positive'),
#  (['VirginAmerica',
#    "n't",
#    'today',
#    '...',
#    'Must',
#    'mean',
#    'need',
#    'take',
#    'another',
#    'trip'],
#   'neutral'),
#  (['VirginAmerica',
#    "'s",
#    'really',
#    'aggressive',
#    'blast',
#    'obnoxious',
#    '``',
#    'entertainment',
#    "''",
#    'guest',
#    'face',
#    'amp',
#    'little',
#    'recourse'],
#   'negative'),
#  (['VirginAmerica', "'s", 'really', 'big', 'bad', 'thing'], 'negative'),
#  (['VirginAmerica',
#    'seriously',
#    'would',
#    'pay',
#    '30',
#    'flight',
#    'seat',
#    "n't",
#    'play',
#    "'s",
#    'really',
#    'bad',
#    'thing',
#    'fly',
#    'VA'],
#   'negative'),
#  (['VirginAmerica',
#    'yes',
#    'nearly',
#    'every',
#    'time',
#    'fly',
#    'VX',
#    '“',
#    'ear',
#    'worm',
#    '”',
#    '’',
#    'go',
#    'away'],
#   'positive'),
#  (['VirginAmerica',
#    'Really',
#    'miss',
#    'prime',
#    'opportunity',
#    'Men',
#    'Without',
#    'Hats',
#    'parody',
#    'http',
#    '//t.co/mWpG7grEZP'],
#   'neutral'),
#  (['virginamerica', 'Well', "didn't…but", '-D'], 'positive'),
#  (['VirginAmerica', 'amaze', 'arrive', 'hour', 'early', "'re", 'good'],
#   'positive'),
#  (['VirginAmerica',
#    'know',
#    'suicide',
#    'second',
#    'lead',
#    'cause',
#    'death',
#    'among',
#    'teen',
#    '10-24'],
#   'neutral'),
#  (['VirginAmerica',
#    'lt',
#    '3',
#    'pretty',
#    'graphic',
#    'much',
#    'well',
#    'minimal',
#    'iconography'],
#   'positive'),
#  (['VirginAmerica',
#    'great',
#    'deal',
#    'Already',
#    'think',
#    '2nd',
#    'trip',
#    'Australia',
#    'amp',
#    "n't",
#    'even',
#    'go',
#    '1st',
#    'trip',
#    'yet',
#    'p'],
#   'positive'),
#  (['VirginAmerica',
#    'virginmedia',
#    "'m",
#    'fly',
#    'fabulous',
#    'Seductive',
#    'sky',
#    'U',
#    'take',
#    'stress',
#    'away',
#    'travel',
#    'http',
#    '//t.co/ahlXHhKiyn'],
#   'positive'),
#  (['VirginAmerica', 'Thanks'], 'positive'),
#  (['VirginAmerica', 'SFO-PDX', 'schedule', 'still', 'MIA'], 'negative'),
#  (['VirginAmerica',
#    'excite',
#    'first',
#    'cross',
#    'country',
#    'flight',
#    'LAX',
#    'MCO',
#    "'ve",
#    'heard',
#    'nothing',
#    'great',
#    'thing',
#    'Virgin',
#    'America',
#    '29DaysToGo'],
#   'positive'),
#  (['VirginAmerica',
#    'flew',
#    'NYC',
#    'SFO',
#    'last',
#    'week',
#    'could',
#    "n't",
#    'fully',
#    'sit',
#    'seat',
#    'due',
#    'two',
#    'large',
#    'gentleman',
#    'either',
#    'side',
#    'HELP'],
#   'negative'),
#  (['❤️', 'fly', 'VirginAmerica', '☺️👍'], 'positive'),
#  (['VirginAmerica',
#    'know',
#    'would',
#    'amazingly',
#    'awesome',
#    'BOS-FLL',
#    'PLEASE',
#    'want',
#    'fly'],
#   'positive'),
#  (['VirginAmerica',
#    'first',
#    'fare',
#    'May',
#    'three',
#    'time',
#    'carrier',
#    'seat',
#    'available',
#    'select'],
#   'negative'),
#  (['VirginAmerica', 'love', 'graphic', 'http', '//t.co/UT5GrRwAaA'],
#   'positive'),
#  (['VirginAmerica', 'love', 'hipster', 'innovation', 'feel', 'good', 'brand'],
#   'positive'),
#  (['VirginAmerica',
#    'make',
#    'BOS',
#    'gt',
#    'LAS',
#    'non',
#    'stop',
#    'permanently',
#    'anytime',
#    'soon'],
#   'neutral'),
#  (['VirginAmerica',
#    'guy',
#    'mess',
#    'seat',
#    '..',
#    'reserve',
#    'seat',
#    'friend',
#    'guy',
#    'give',
#    'seat',
#    'away',
#    '...',
#    '😡',
#    'want',
#    'free',
#    'internet'],
#   'negative'),
#  (['VirginAmerica',
#    'status',
#    'match',
#    'program',
#    'apply',
#    "'s",
#    'three',
#    'week',
#    'Called',
#    'email',
#    'response'],
#   'negative'),
#  (['VirginAmerica',
#    'happen',
#    '2',
#    'ur',
#    'vegan',
#    'food',
#    'option',
#    'least',
#    'say',
#    'ur',
#    'site',
#    'know',
#    'wo',
#    "n't",
#    'able',
#    '2',
#    'eat',
#    'anything',
#    'next',
#    '6',
#    'hr',
#    'fail'],
#   'negative'),
#  (['VirginAmerica', 'miss', "n't", 'worry', "'ll", 'together', 'soon'],
#   'neutral'),
#  (['VirginAmerica',
#    'amaze',
#    'ca',
#    "n't",
#    'get',
#    'cold',
#    'air',
#    'vent',
#    'VX358',
#    'noair',
#    'worstflightever',
#    'roast',
#    'SFOtoBOS'],
#   'negative'),
#  (['VirginAmerica',
#    'LAX',
#    'EWR',
#    'Middle',
#    'seat',
#    'red',
#    'eye',
#    'noob',
#    'maneuver',
#    'sendambien',
#    'andchexmix'],
#   'neutral'),
#  (['VirginAmerica',
#    'hi',
#    'bked',
#    'cool',
#    'birthday',
#    'trip',
#    'ca',
#    "n't",
#    'add',
#    'elevate',
#    'cause',
#    'enter',
#    'middle',
#    'name',
#    'Flight',
#    'Booking',
#    'Problems',
#    '😢'],
#   'negative'),
#  (['VirginAmerica',
#    'hour',
#    'operation',
#    'Club',
#    'SFO',
#    'post',
#    'online',
#    'current'],
#   'neutral'),
#  (['VirginAmerica',
#    'help',
#    'left',
#    'expensive',
#    'headphone',
#    'flight',
#    '89',
#    'IAD',
#    'LAX',
#    'today',
#    'Seat',
#    '2A',
#    'one',
#    'answer',
#    'L',
#    'amp',
#    'F',
#    'number',
#    'LAX'],
#   'negative'),
#  (['VirginAmerica',
#    'await',
#    'return',
#    'phone',
#    'call',
#    'would',
#    'prefer',
#    'use',
#    'online',
#    'self-service',
#    'option'],
#   'negative'),
#  (['VirginAmerica',
#    'great',
#    'news',
#    'America',
#    'could',
#    'start',
#    'flight',
#    'Hawaii',
#    'end',
#    'year',
#    'http',
#    '//t.co/r8p2Zy3fe4',
#    'via',
#    'Pacificbiznews'],
#   'positive'),
#  (['Nice',
#    'RT',
#    'VirginAmerica',
#    'Vibe',
#    'moodlight',
#    'takeoff',
#    'touchdown',
#    'MoodlitMonday',
#    'ScienceBehindTheExperience',
#    'http',
#    '//t.co/Y7O0uNxTQP'],
#   'neutral'),
#  (['VirginAmerica',
#    'Moodlighting',
#    'way',
#    'fly',
#    'Best',
#    'experience',
#    'EVER',
#    'Cool',
#    'calm',
#    '💜✈',
#    'MoodlitMonday'],
#   'positive'),
#  (['VirginAmerica',
#    'freddieawards',
#    'Done',
#    'do',
#    'Best',
#    'airline',
#    'around',
#    'hand'],
#   'positive'),
#  (['VirginAmerica', 'book', 'flight', 'Hawaii'], 'neutral'),
#  (['VirginAmerica',
#    'chat',
#    'support',
#    'work',
#    'site',
#    'http',
#    '//t.co/vhp2GtDWPk'],
#   'negative'),
#  (['VirginAmerica',
#    'View',
#    'downtown',
#    'Los',
#    'Angeles',
#    'Hollywood',
#    'Sign',
#    'beyond',
#    'rain',
#    'mountain',
#    'http',
#    '//t.co/Dw5nf0ibtr'],
#   'positive'),
#  (['VirginAmerica',
#    'Hey',
#    'first',
#    'time',
#    'flyer',
#    'next',
#    'week',
#    'excite',
#    "'m",
#    'hard',
#    'time',
#    'get',
#    'flight',
#    'add',
#    'Elevate',
#    'account',
#    'Help'],
#   'negative'),
#  (['VirginAmerica',
#    'plz',
#    'help',
#    'win',
#    'bid',
#    'upgrade',
#    'flight',
#    '2/27',
#    'LAX',
#    '--',
#    'gt',
#    'SEA',
#    '🍷👍💺✈️'],
#   'neutral'),
#  (['VirginAmerica',
#    'unused',
#    'ticket',
#    'move',
#    'new',
#    'city',
#    "n't",
#    'fly',
#    'fly',
#    'expires',
#    'travelhelp'],
#   'neutral'),
#  (['VirginAmerica',
#    'flight',
#    'leave',
#    'Dallas',
#    'Seattle',
#    'time',
#    'Feb',
#    '24'],
#   'neutral'),
#  (['VirginAmerica', "'m", 'elevategold', 'good', 'reason', 'rock'],
#   'positive'),
#  (['VirginAmerica',
#    'DREAM',
#    'http',
#    '//t.co/oA2dRfAoQ2',
#    'http',
#    '//t.co/lWWdAc2kHx'],
#   'neutral'),
#  (['VirginAmerica', 'wow', 'blew', 'mind'], 'positive'),
#  (['VirginAmerica',
#    'ladygaga',
#    'carrieunderwood',
#    'last',
#    'night',
#    'tribute',
#    'SoundOfMusic',
#    'Oscars2015',
#    'ladygaga',
#    'think',
#    'carrieunderwood',
#    'agree'],
#   'neutral'),
#  (['VirginAmerica', 'ladygaga', 'carrieunderwood', 'entertain'], 'neutral'),
#  (['VirginAmerica',
#    'flight',
#    '769',
#    "'s",
#    'way',
#    'suppose',
#    'take',
#    '30',
#    'minute',
#    'ago',
#    'Website',
#    'still',
#    'show',
#    '``',
#    'Time',
#    "''",
#    '``',
#    'Flight',
#    "''",
#    'Thanks'],
#   'neutral'),
#  (['VirginAmerica',
#    'ladygaga',
#    'carrieunderwood',
#    'Julie',
#    'Andrews',
#    'way',
#    'though',
#    'ladygaga',
#    'impressive',
#    'Carrieunderwood'],
#   'positive'),
#  (['VirginAmerica', 'wish', 'flew', 'Atlanta', '...', 'Soon'], 'neutral'),
#  (['VirginAmerica',
#    'ladygaga',
#    'carrieunderwood',
#    'Julie',
#    'Andrews',
#    'Hands'],
#   'neutral'),
#  (['VirginAmerica', 'flight', 'leave', 'Dallas', 'LA', 'February', '24th'],
#   'neutral'),
#  (['VirginAmerica',
#    'hi',
#    "'m",
#    'excite',
#    '99',
#    'LGA-',
#    'gt',
#    'DAL',
#    'deal-',
#    "'ve",
#    'try',
#    '2',
#    'book',
#    'since',
#    'last',
#    'week',
#    'amp',
#    'page',
#    'never',
#    'load',
#    'thx'],
#   'negative'),
#  (['VirginAmerica', 'know', 'Need', 'spotify', 'stat', 'guiltypleasures'],
#   'positive'),
#  (['VirginAmerica',
#    'ladygaga',
#    'carrieunderwood',
#    "'m",
#    'Lady',
#    'Gaga',
#    'amaze',
#    '😊'],
#   'positive'),
#  (['VirginAmerica', 'ladygaga', 'carrieunderwood', 'Carrie'], 'neutral'),
#  (['VirginAmerica',
#    'New',
#    'marketing',
#    'song',
#    'http',
#    '//t.co/F2LFULCbQ7',
#    'let',
#    'u',
#    'know',
#    'think'],
#   'neutral'),
#  (['VirginAmerica',
#    'ladygaga',
#    'carrieunderwood',
#    'Julie',
#    'Andrews',
#    'first',
#    'Lady',
#    'Gaga',
#    'wow',
#    "'d",
#    'last',
#    'night',
#    'Carrie',
#    'Meh'],
#   'neutral'),
#  (['VirginAmerica',
#    'call',
#    '3-4',
#    'week',
#    'ago',
#    'add',
#    '3',
#    'flight',
#    '2014',
#    'Elevate',
#    '...',
#    'still',
#    "n't",
#    'show',
#    '...',
#    'help'],
#   'negative'),
#  (['VirginAmerica',
#    'ladygaga',
#    'carrieunderwood',
#    'great',
#    'go',
#    'CarrieUnderwood',
#    '😍👌'],
#   'neutral'),
#  (['VirginAmerica',
#    'LadyGaga',
#    'CarrieUnderwood',
#    'Sorry',
#    'Mary',
#    'Martin',
#    'first'],
#   'neutral'),
#  (['VirginAmerica',
#    'ladygaga',
#    'carrieunderwood',
#    'love',
#    'three',
#    'really',
#    'ca',
#    "n't",
#    'beat',
#    'classic'],
#   'positive'),
#  (['VirginAmerica',
#    'Flight',
#    '0736',
#    'DAL',
#    'DCA',
#    '2/24',
#    '2:10pm',
#    'Tried',
#    'check',
#    'could',
#    'Status',
#    'please'],
#   'neutral'),
#  (['VirginAmerica',
#    'heyyyy',
#    'guyyyys',
#    '..',
#    'try',
#    'get',
#    'hour',
#    'someone',
#    'call',
#    'please'],
#   'negative'),
#  (['VirginAmerica',
#    'Hi',
#    'Virgin',
#    "'m",
#    'hold',
#    '40-50',
#    'minute',
#    '--',
#    'earlier',
#    'flight',
#    'LA',
#    'NYC',
#    'tonight',
#    'earlier',
#    '11:50pm'],
#   'negative'),
#  (['VirginAmerica',
#    'Congrats',
#    'win',
#    'Travelzoo',
#    'award',
#    'Best',
#    'Deals',
#    'Airline',
#    'US',
#    'http',
#    '//t.co/kj1iljaebV'],
#   'positive'),
#  (['VirginAmerica', 'everything', 'fine', 'lose', 'bag'], 'negative'),
#  (['virginamerica',
#    'Need',
#    'change',
#    'reservation',
#    'Virgin',
#    'credit',
#    'card',
#    'need',
#    'modify',
#    'phone',
#    'waive',
#    'change',
#    'fee',
#    'online'],
#   'neutral'),
#  (['VirginAmerica',
#    'email',
#    'customer',
#    'service',
#    'team',
#    'Let',
#    'know',
#    'need',
#    'track',
#    'number'],
#   'neutral'),
#  (['VirginAmerica', 'hi', 'book', 'flight', 'need', 'add', 'baggage'],
#   'neutral'),
#  (['VirginAmerica',
#    'airline',
#    'awesome',
#    'lax',
#    'loft',
#    'need',
#    'step',
#    'game',
#    '40',
#    'dirty',
#    'table',
#    'floor',
#    'http',
#    '//t.co/hy0VrfhjHt'],
#   'negative'),
#  (['VirginAmerica',
#    'worried',
#    "'s",
#    'great',
#    'ride',
#    'new',
#    'plane',
#    'great',
#    'crew',
#    'airline',
#    'like'],
#   'positive'),
#  (['VirginAmerica',
#    'awesome',
#    'flew',
#    'yall',
#    'Sat',
#    'morning',
#    'way',
#    'correct',
#    'bill'],
#   'positive'),
#  (['VirginAmerica',
#    'watch',
#    'best',
#    'student',
#    'film',
#    'country',
#    '35,000',
#    'foot',
#    'CMFat35000feet',
#    'http',
#    '//t.co/KEK5pDMGiF'],
#   'neutral'),
#  (['VirginAmerica',
#    'first',
#    'time',
#    'fly',
#    'different',
#    'rate/policy',
#    'medium',
#    'Bags',
#    'Thanks'],
#   'neutral'),
#  (['VirginAmerica',
#    'go',
#    'customer',
#    'service',
#    'anyway',
#    'speak',
#    'human',
#    'asap',
#    'Thank'],
#   'negative'),
#  (['VirginAmerica', 'happen', 'Doom'], 'neutral'),
#  (['VirginAmerica',
#    'ca',
#    "n't",
#    'supp',
#    'biz',
#    'traveler',
#    'like',
#    'SouthwestAir',
#    'customer',
#    'service',
#    'like',
#    'JetBlue',
#    'neverflyvirginforbusiness'],
#   'negative'),
#  (['VirginAmerica',
#    "'ve",
#    'apply',
#    'member',
#    'inflight',
#    'crew',
#    'team',
#    '...',
#    'Im',
#    '100',
#    'interested',
#    'flightattendant',
#    'dreampath',
#    '-G'],
#   'positive'),
#  (['VirginAmerica',
#    "'re",
#    'best',
#    'Whenever',
#    'begrudgingly',
#    'use',
#    'airline',
#    "'m",
#    'delayed',
#    'Late',
#    'Flight'],
#   'negative'),
#  (['VirginAmerica',
#    'interest',
#    'fly',
#    'Cancelled',
#    'Flight',
#    'next',
#    'four',
#    'flight',
#    'planned.',
#    'neverflyvirginforbusiness'],
#   'negative'),
#  (['VirginAmerica',
#    'disappoint',
#    'experience',
#    'share',
#    'every',
#    'business',
#    'traveler',
#    'meet',
#    'neverflyvirgin'],
#   'negative'),
#  (['VirginAmerica',
#    '’',
#    'trouble',
#    'add',
#    'flight',
#    'wife',
#    'book',
#    'Elevate',
#    'account',
#    'Help',
#    'http',
#    '//t.co/pX8hQOKS3R'],
#   'negative'),
#  (['VirginAmerica',
#    'Ca',
#    "n't",
#    'bring',
#    'reservation',
#    'online',
#    'use',
#    'Flight',
#    'Booking',
#    'Problems',
#    'code'],
#   'neutral'),
#  (['VirginAmerica',
#    'Random',
#    'Q',
#    "'s",
#    'distribution',
#    'elevate',
#    'avatar',
#    'bet',
#    'kitty',
#    'disproportionate',
#    'share',
#    'http',
#    '//t.co/APtZpuROp4'],
#   'neutral'),
#  (['VirginAmerica',
#    'lt',
#    '3',
#    'Flying',
#    'VA',
#    'Life',
#    'happens',
#    'try',
#    'change',
#    'trip',
#    'JPERHI',
#    'help.VA',
#    'home',
#    'page',
#    'let'],
#   'neutral'),
#  (['VirginAmerica', 'site', 'back'], 'negative'),
#  (['VirginAmerica', '``', 'RNP', "''", '``', 'Yeah', 'know', "''"], 'neutral'),
#  (['VirginAmerica',
#    'hi',
#    'get',
#    'point',
#    'elevate',
#    'account',
#    'recent',
#    'flight',
#    'add',
#    'flight',
#    'point',
#    'account'],
#   'neutral'),
#  (['VirginAmerica',
#    'like',
#    'TV',
#    'interest',
#    'video',
#    'disappointed',
#    'Cancelled',
#    'Flightled',
#    'flight',
#    'flight',
#    'go',
#    'jfk',
#    'Saturday'],
#   'negative'),
#  (['VirginAmerica',
#    'land',
#    'LAX',
#    'hour',
#    'Late',
#    'Flight',
#    'bag',
#    'check',
#    'business',
#    'travel',
#    'friendly',
#    'nomorevirgin'],
#   'negative'),
#  (['VirginAmerica', 'flight', '345', 'redirect'], 'neutral'),
#  (['VirginAmerica',
#    'website',
#    'BTW',
#    'new',
#    'website',
#    "n't",
#    'great',
#    'user',
#    'experience',
#    'Time',
#    'another',
#    'redesign'],
#   'negative'),
#  (['VirginAmerica',
#    'ca',
#    "n't",
#    'check',
#    'add',
#    'bag',
#    'website',
#    "n't",
#    'work',
#    "'ve",
#    'try',
#    'desktop',
#    'mobile',
#    'http',
#    '//t.co/AvyqdMpi1Y'],
#   'negative'),
#  (['VirginAmerica',
#    'Let',
#    '2',
#    'scan',
#    'passenger',
#    'leave',
#    'plane',
#    'told',
#    'someone',
#    'remove',
#    'bag',
#    '1st',
#    'class',
#    'bin',
#    'uncomfortable'],
#   'negative'),
#  (['virginamerica',
#    'phone',
#    'number',
#    'ca',
#    "n't",
#    'find',
#    'call',
#    'flight',
#    'reservation'],
#   'negative'),
#  (['VirginAmerica',
#    'anyone',
#    'anything',
#    'today',
#    'Website',
#    'useless',
#    'one',
#    'answer',
#    'phone'],
#   'negative'),
#  (['VirginAmerica',
#    'try',
#    'add',
#    'boy',
#    'Prince',
#    'ressie',
#    'SF',
#    'Thursday',
#    'VirginAmerica',
#    'LAX',
#    'http',
#    '//t.co/GsB2J3c4gM'],
#   'neutral'),
#  (['VirginAmerica',
#    'must',
#    'traveler',
#    'miss',
#    'flight',
#    'Late',
#    'Flight',
#    'check',
#    'bag',
#    'miss',
#    'morning',
#    'appointment',
#    'lose',
#    'business',
#    'sfo2lax'],
#   'negative'),
#  (['VirginAmerica', 'check', 'new', 'music', 'http', '//t.co/maRcnOCWzn'],
#   'neutral'),
#  (['virginamerica',
#    "'s",
#    'direct',
#    'flight',
#    'FLL-',
#    'gt',
#    'SFO',
#    'unexpected',
#    'layover',
#    'Vegas',
#    '4',
#    'fuel',
#    'yet',
#    'peep',
#    'next',
#    'bought',
#    'Vegas',
#    'flight',
#    'sneaky'],
#   'negative'),
#  (['VirginAmerica',
#    'Late',
#    'Flight',
#    'bag',
#    'check',
#    'lose',
#    'business',
#    'miss',
#    'flight',
#    'apt',
#    'Three',
#    'people',
#    'flight',
#    'exp'],
#   'negative'),
#  (['VirginAmerica',
#    'amaze',
#    'customer',
#    'service',
#    '💕💕',
#    'RaeAnn',
#    'SF',
#    "'s",
#    'best',
#    'customerservice',
#    'virginamerica',
#    'fly'],
#   'positive'),
#  (['VirginAmerica', 'call', 'service', 'line', 'hung', 'awesome', 'sarcasm'],
#   'negative'),
#  (['VirginAmerica',
#    'site',
#    'trip',
#    "'m",
#    'try',
#    'check',
#    "'m",
#    'get',
#    'plain',
#    'text',
#    'version',
#    'reluctant',
#    'enter',
#    'card',
#    'info'],
#   'negative'),
#  (['VirginAmerica',
#    'schedule',
#    'SFO',
#    '2',
#    'DAL',
#    'flight',
#    '714',
#    'today',
#    'Changed',
#    '24th',
#    'due',
#    'weather',
#    'Looks',
#    'like',
#    'flight',
#    'still'],
#   'neutral'),
#  (['VirginAmerica',
#    'getaway',
#    'deal',
#    'May',
#    '59',
#    'one-way',
#    'Lots',
#    'cool',
#    'city',
#    'http',
#    '//t.co/tZZJhuIbCH',
#    'CheapFlights',
#    'FareCompare'],
#   'positive'),
#  (['VirginAmerica',
#    'getaway',
#    'deal',
#    'May',
#    '59',
#    'one-way',
#    'Lots',
#    'cool',
#    'city',
#    'http',
#    '//t.co/RPdBpX3wNd',
#    'CheapFlights',
#    'FareCompare'],
#   'neutral'),
#  (['VirginAmerica',
#    'getaway',
#    'deal',
#    'May',
#    '59',
#    'one-way',
#    'Lots',
#    'cool',
#    'city',
#    'http',
#    '//t.co/B2Xi4YG5T8',
#    'CheapFlights',
#    'FareCompare'],
#   'positive'),
#  (['VirginAmerica',
#    'getaway',
#    'deal',
#    'May',
#    '59',
#    'one-way',
#    'Lots',
#    'cool',
#    'city',
#    'http',
#    '//t.co/QDlJHslOI5',
#    'CheapFlights',
#    'FareCompare'],
#   'neutral'),
#  (['VirginAmerica', 'great', 'week', '🌞✈'], 'positive'),
#  (['VirginAmerica',
#    'come',
#    'back',
#    'PHL',
#    'already',
#    'need',
#    'take',
#    'u',
#    'horrible',
#    'cold',
#    'pleasecomeback',
#    'http',
#    '//t.co/gLXFwP6nQH'],
#   'positive'),
#  (['VirginAmerica',
#    'concerned',
#    'fly',
#    'plane',
#    'need',
#    'delayed',
#    'due',
#    '``',
#    'tech',
#    'stop',
#    "''"],
#   'negative'),
#  (['VirginAmerica',
#    'best',
#    'airline',
#    'flown',
#    'on.Easy',
#    'change',
#    'reservation',
#    'helpful',
#    'representative',
#    'amp',
#    'comfortable',
#    'fly',
#    'experience'],
#   'positive'),
#  (['VirginAmerica',
#    'Another',
#    'rep',
#    'kick',
#    'butt',
#    'Naelah',
#    'represent',
#    'team',
#    'beautifully',
#    'Thank'],
#   'positive'),
#  (['VirginAmerica',
#    'beautiful',
#    'front-end',
#    'design',
#    'right',
#    'cool',
#    'still',
#    'book',
#    'ticket',
#    'b/c',
#    'back-end',
#    'secure'],
#   'positive'),
#  (['VirginAmerica',
#    'Love',
#    'team',
#    'run',
#    'Gate',
#    'E9',
#    'LAS',
#    'tonight',
#    'Waited',
#    'delayed',
#    'flight',
#    'kept',
#    'thing',
#    'entertain'],
#   'positive'),
#  (['VirginAmerica',
#    'Use',
#    'another',
#    'browser',
#    '2015',
#    'amp',
#    'brand',
#    'reputation',
#    'built',
#    'tech',
#    'response',
#    "n't",
#    'cross-browser',
#    'compatible',
#    'website'],
#   'negative'),
#  (['VirginAmerica',
#    'flight',
#    'Flight',
#    'Booking',
#    'Problems',
#    'site',
#    'totally',
#    'Folks',
#    'problem'],
#   'negative'),
#  (['VirginAmerica',
#    'like',
#    'customer',
#    'service',
#    '40',
#    'min',
#    'delay',
#    'connect',
#    'passenger',
#    'seem',
#    'long',
#    'VA370'],
#   'negative'),
#  (['VirginAmerica',
#    'thanks',
#    'outstanding',
#    'NYC-JFK',
#    'crew',
#    'move',
#    'mountain',
#    'get',
#    'home',
#    'San',
#    'Francisco',
#    'tonight'],
#   'positive'),
#  (['VirginAmerica',
#    'absolute',
#    'best',
#    'team',
#    'customer',
#    'service',
#    'ever',
#    'Every',
#    'time',
#    'fly',
#    "'m",
#    'delighted',
#    'Thank'],
#   'positive'),
#  (['VirginAmerica',
#    'provide',
#    'complimentary',
#    'upgrade',
#    'first',
#    'class',
#    'available',
#    'seat'],
#   'neutral'),
#  (['VirginAmerica',
#    'need',
#    'change',
#    'flight',
#    'thats',
#    'schedule',
#    '9',
#    'hour',
#    '120',
#    'min',
#    'wait',
#    'time',
#    'phone',
#    'Im',
#    'call',
#    'intern',
#    'Help'],
#   'negative'),
#  (['VirginAmerica',
#    'completely',
#    'awesome',
#    'experience',
#    'last',
#    'month',
#    'BOS-LAS',
#    'nonstop',
#    'Thanks',
#    'awesome',
#    'flight',
#    'depart',
#    'time',
#    'VAbeatsJblue'],
#   'positive'),
#  (['VirginAmerica', 'watch', 'Oscars2015', 'JFK-', 'gt', 'SFO', 'flight'],
#   'neutral'),
#  (['VirginAmerica', 'flight', '882', 'Cancelled', 'Flightled'], 'neutral'),
#  (['VirginAmerica',
#    'fail',
#    'customer',
#    'check',
#    'process',
#    'link',
#    'TSA',
#    'pre-check'],
#   'negative'),
#  (['VirginAmerica',
#    'FiDiFamilies',
#    'u',
#    'Terrible',
#    'airline',
#    'give',
#    'u',
#    'hotel',
#    'hotline',
#    'number',
#    'say',
#    'sorry'],
#   'negative'),
#  (['VirginAmerica',
#    'flight',
#    'number',
#    '276',
#    'SFO',
#    'Cabo',
#    'San',
#    'Lucas',
#    'arrive',
#    'yet'],
#   'neutral'),
#  (['VirginAmerica',
#    'ChrysiChrysic',
#    'assistance',
#    'yesterday',
#    'u',
#    'Cancelled',
#    'Flightled',
#    'flight',
#    'give',
#    'u',
#    'hotel',
#    'hotline',
#    'Shame'],
#   'negative'),
#  (['VirginAmerica', 'Another', 'delayed', 'flight', 'likingyoulessandless'],
#   'negative'),
#  (['VirginAmerica',
#    'need',
#    'register',
#    'service',
#    'dog',
#    'first',
#    'class',
#    'ticket',
#    'SFO',
#    'gt',
#    'Dulles',
#    'phone',
#    'queue',
#    'hour',
#    'longer',
#    'Pls',
#    'advise'],
#   'negative'),
#  (['virginamerica',
#    'ROCK',
#    'make',
#    'watch',
#    'Oscars',
#    'flight',
#    'redcarpet',
#    'oscar',
#    'oscars2015'],
#   'positive'),
#  (['VirginAmerica',
#    'reallytallchris',
#    'drop',
#    'track',
#    '...',
#    'http',
#    '//t.co/zv2pt6TRK9'],
#   'neutral'),
#  (['VirginAmerica', 'always', 'Xoxo'], 'positive'),
#  (['VirginAmerica',
#    'ca',
#    "n't",
#    'book',
#    'seat',
#    'flight',
#    'buy',
#    'even',
#    'check',
#    'Creates',
#    'much',
#    'anxiety',
#    'frustrate'],
#   'negative'),
#  (['VirginAmerica',
#    "'d",
#    'think',
#    'pay',
#    'extra',
#    '100',
#    'buck',
#    'RT',
#    'luggage',
#    'might',
#    'afford',
#    'hire',
#    'extra',
#    'hand',
#    'sfo',
#    'lame'],
#   'negative'),
#  (['VirginAmerica',
#    'best',
#    'customer',
#    'service',
#    'rep',
#    'world',
#    'irmafromDallas',
#    'take',
#    'cake'],
#   'positive'),
#  (['VirginAmerica',
#    'find',
#    'u',
#    'flt',
#    'LAX',
#    'sooner',
#    'midnight',
#    'Monday',
#    'would',
#    'great',
#    'customer',
#    'service',
#    '😃'],
#   'neutral'),
#  (['VirginAmerica',
#    'please',
#    'provide',
#    'status',
#    'flight',
#    '769',
#    'cant',
#    'imagine',
#    "'s",
#    'time',
#    'Web',
#    'indicates',
#    'dude',
#    'weather',
#    'and/or',
#    'Dallas'],
#   'negative'),
#  (['VirginAmerica',
#    'amaze',
#    'staff',
#    'amp',
#    'super',
#    'helpful',
#    'ran',
#    'WaltDisneyWorld',
#    'PrincessHalf',
#    'spoil',
#    'comfort'],
#   'positive'),
#  (['VirginAmerica',
#    'paid',
#    'premium',
#    'fly',
#    'across',
#    'country',
#    'Cancelled',
#    'Flight',
#    'flight',
#    'offer',
#    'check',
#    'fee',
#    'upgrade',
#    'love',
#    'Sad',
#    'face'],
#   'negative'),
#  (['VirginAmerica',
#    'question',
#    'possible',
#    'book',
#    'seat',
#    'infant',
#    '2',
#    "'s",
#    'give',
#    'option',
#    'want',
#    'seat'],
#   'negative'),
#  (['Always',
#    'together',
#    "'re",
#    'welcome',
#    'RT',
#    'VirginAmerica',
#    'jessicajaymes',
#    "'re",
#    'welcome'],
#   'positive'),
#  (['virginamerica',
#    'flight',
#    'home',
#    'dc',
#    'sunset',
#    'globe',
#    'backtowinter',
#    'back',
#    'work',
#    'refresh',
#    'http',
#    '//t.co/VX9vBCTdLf'],
#   'positive'),
#  (['VirginAmerica',
#    "n't",
#    'understand',
#    'need',
#    'DM',
#    'give',
#    'answer',
#    'damage',
#    'luggage',
#    'policy'],
#   'negative'),
#  (['VirginAmerica', 'mean', "n't", 'policy', 'destroyed', 'luggage'],
#   'negative'),
#  (['VirginAmerica',
#    'special',
#    'assistance',
#    'travel',
#    'alone',
#    'w/2',
#    'kid',
#    '1',
#    'infant',
#    'Priority',
#    'boarding'],
#   'neutral'),
#  (['VirginAmerica',
#    'thank',
#    'check',
#    'ticket',
#    'purchase',
#    'customer',
#    'happy'],
#   'positive'),
#  (['VirginAmerica', 'website', 'ever', 'come', 'back', 'online'], 'neutral'),
#  (['VirginAmerica',
#    'Flight',
#    '713',
#    'Love',
#    'Field',
#    'SFO',
#    'definitely',
#    'Cancelled',
#    'Flightled',
#    'Monday',
#    'February',
#    '23'],
#   'neutral'),
#  (['VirginAmerica', 'flight', '0769', 'LGA', 'DFW', 'time'], 'neutral'),
#  (['VirginAmerica',
#    'driver',
#    'license',
#    'expire',
#    'little',
#    'month',
#    'fly',
#    'Friday',
#    'morning',
#    'use',
#    'expire',
#    'license'],
#   'neutral'),
#  (['VirginAmerica',
#    'problem',
#    'Flight',
#    'Booking',
#    'Problems',
#    'web',
#    'site',
#    'keep',
#    'give',
#    'error',
#    'contact',
#    'phone',
#    'phone',
#    '30',
#    'minute',
#    'wait'],
#   'negative'),
#  (['VirginAmerica',
#    'reschedule',
#    'Cancelled',
#    'Flightled',
#    'flight',
#    'online',
#    'change',
#    'button',
#    'greyed'],
#   'negative'),
#  (['VirginAmerica',
#    'rang',
#    'wait',
#    '35',
#    'minute',
#    'book',
#    'ticket',
#    'vendor',
#    'fix',
#    'site'],
#   'negative'),
#  (['VirginAmerica',
#    'get',
#    'flight',
#    'told',
#    '4:50',
#    'today',
#    '..',
#    'checked',
#    'email',
#    '4',
#    '50',
#    'TOMORROW',
#    'unacceptable'],
#   'negative'),
#  (['VirginAmerica',
#    'flight',
#    'lga',
#    'Cancelled',
#    'Flighted',
#    "'re",
#    'stuck',
#    'Dallas',
#    'call',
#    'reschedule',
#    'told',
#    'could',
#    'get',
#    'flight',
#    'today',
#    '...',
#    '1/2'],
#   'negative'),
#  (['virginamerica',
#    "n't",
#    'pairing',
#    'include',
#    'red',
#    'wine',
#    'white',
#    'offer',
#    'redwineisbetter'],
#   'negative'),
#  (['VirginAmerica', 'website'], 'negative'),
#  (['VirginAmerica',
#    'site',
#    'seem',
#    'little',
#    'wonked',
#    'right',
#    'May',
#    'want',
#    'look',
#    'Tried',
#    'two',
#    'browser',
#    'CSS',
#    'http',
#    '//t.co/8qsQMM7KF2'],
#   'negative'),
#  (['VirginAmerica',
#    "'m",
#    'disappointed',
#    'agent',
#    'designate',
#    'silver',
#    'status',
#    'check',
#    'line',
#    'Dulles_Airport',
#    'close',
#    'assist',
#    'pasengers'],
#   'negative'),
#  (['VirginAmerica',
#    'Plans',
#    'Include',
#    'Austin',
#    'Dallas',
#    'Route',
#    'TopNews',
#    'Arab',
#    'Emirates',
#    'http',
#    '//t.co/aqZWecOkk2'],
#   'neutral'),
#  (['VirginAmerica',
#    'normal',
#    'receive',
#    'reply',
#    'Central',
#    'Baggage',
#    'baggageissues',
#    'smh'],
#   'negative'),
#  (['VirginAmerica',
#    'Logan',
#    'airport',
#    'wait',
#    'checkin',
#    '9am',
#    'flight',
#    'Checkin',
#    'desk',
#    'open'],
#   'negative'),
#  (['VirginAmerica',
#    'jump',
#    'Dallas-Austin',
#    'market',
#    'Dallas_News',
#    'http',
#    '//t.co/EwwGi97gdx'],
#   'neutral'),
#  (['VirginAmerica',
#    'Beats',
#    'EPS',
#    'Views',
#    'Takes',
#    'SouthwestAir',
#    'VA',
#    'LUV',
#    'Investor',
#    "'s",
#    'Business',
#    'Daily',
#    'http',
#    '//t.co/FLwmGDAHxu'],
#   'neutral'),
#  (['VirginAmerica', 'Lister', 'show', 'Monday', '1230', '130'], 'neutral'),
#  (['VirginAmerica',
#    'begin',
#    'Dallas-Austin',
#    'flight',
#    'April',
#    '88.9',
#    'KETR',
#    'http',
#    '//t.co/SSUVWwkyHH'],
#   'neutral'),
#  (['VirginAmerica',
#    'congrats',
#    'get',
#    'business',
#    'EWR',
#    'SFO/LAX',
#    'Fuck',
#    'united',
#    'fl1289',
#    'SFO/EWR',
#    'clincher',
#    '...'],
#   'negative'),
#  (['VirginAmerica',
#    'apply',
#    '2',
#    'week',
#    'ago',
#    "n't",
#    'heard',
#    'back',
#    "'m",
#    'fly',
#    'week',
#    'disappointed'],
#   'negative'),
#  (['VirginAmerica', "'d", 'love', 'know', 'policy', 'damage', 'luggage'],
#   'neutral'),
#  (['VirginAmerica', 'Thank', 'follow'], 'positive'),
#  (['VirginAmerica',
#    'many',
#    'apology',
#    'r',
#    'bad',
#    'airline',
#    "n't",
#    'even',
#    'respond',
#    'cudtomers'],
#   'negative'),
#  (['VirginAmerica',
#    'shame',
#    'VA',
#    'make',
#    'people',
#    'spend',
#    'money',
#    'strand',
#    'city',
#    'airline',
#    'land',
#    'JFK',
#    'reimburse'],
#   'negative'),
#  (['VirginAmerica', 'TTINAC11', 'DM'], 'neutral'),
#  (['VirginAmerica',
#    'please',
#    'flight',
#    'SJC',
#    'choice',
#    'fly',
#    'Southwest',
#    'Vegas',
#    '😩😭'],
#   'neutral'),
#  (['VirginAmerica',
#    'bad',
#    'say',
#    'take',
#    '10',
#    '14',
#    'day',
#    'via',
#    'confirmation',
#    'email',
#    'inquire',
#    '3',
#    'week',
#    'claim',
#    '6',
#    '8',
#    'week'],
#   'negative'),
#  (['VirginAmerica',
#    'Flight',
#    'BOS',
#    'gt',
#    'LAS',
#    'tomorrow',
#    'Cancelled',
#    'Flightled',
#    'notification',
#    'wait',
#    'time',
#    '1+',
#    'hour',
#    'rebook',
#    'another',
#    'airline'],
#   'negative'),
#  (['😎',
#    'RT',
#    'VirginAmerica',
#    '’',
#    'met',
#    'match',
#    'Got',
#    'status',
#    'another',
#    'airline',
#    'Upgrade',
#    '+restr',
#    'http',
#    '//t.co/RHKaMx9VF5',
#    'http',
#    '//t.co/PYalebgkJt'],
#   'positive'),
#  (['VirginAmerica', 'way', 'fly', 'Elevate', 'Gold'], 'positive'),
#  (['VirginAmerica', 'guy', 'flight', 'CMH'], 'neutral'),
#  (['VirginAmerica',
#    'lot',
#    '``',
#    'apology',
#    "''",
#    'thrown',
#    'customer',
#    'see.Very',
#    'sad',
#    'Thanks',
#    'nothing',
#    'Worst',
#    'airline',
#    'ever'],
#   'negative'),
#  (['VirginAmerica',
#    'flight',
#    'stuff',
#    'wrong',
#    'nothing',
#    'bad',
#    'flight',
#    'ever'],
#   'negative'),
#  (['VirginAmerica',
#    'issue',
#    'find',
#    'miss',
#    'item',
#    'plane',
#    'help',
#    'find',
#    'airport',
#    'plane',
#    'head',
#    'next'],
#   'neutral'),
#  (['VirginAmerica', 'match', 'AmericanAirlines', 'status', 'Cool'],
#   'positive'),
#  (['“',
#    'VirginAmerica',
#    "'ve",
#    'met',
#    'match.Got',
#    'status',
#    'another',
#    'airline',
#    'Upgrade',
#    'http',
#    '//t.co/H952rDKTqy',
#    '”',
#    'asarco_ES_ar',
#    '🙉'],
#   'neutral'),
#  (['VirginAmerica',
#    'try',
#    'book',
#    'flight',
#    'guy',
#    'website',
#    'wo',
#    "n't",
#    'let',
#    '...',
#    'lose',
#    'business'],
#   'negative'),
#  (['VirginAmerica', 'suck'], 'negative'),
#  (['VirginAmerica', 'thanks'], 'positive'),
#  (['VirginAmerica', 'DM', "'d", 'issue', 'persist'], 'negative'),
#  (['VirginAmerica',
#    'never',
#    'rec',
#    "'d",
#    'Cancelled',
#    'Flightlation',
#    'notice',
#    'left',
#    'w',
#    'option',
#    'fly',
#    'PS',
#    'Driving',
#    'LA',
#    'red',
#    'eye',
#    'Mon',
#    'w',
#    'kid'],
#   'negative'),
#  (['VirginAmerica', 'try', 'book', 'flight', 'amp', 'site', '😁'], 'negative'),
#  (['VirginAmerica',
#    'flight',
#    'fly',
#    'Boston',
#    'tomorrow',
#    'need',
#    'home',
#    'Cancelled',
#    'Flightled',
#    'flight',
#    "n't",
#    'anything'],
#   'negative'),
#  (['VirginAmerica',
#    'stink',
#    'Flight',
#    'Cancelled',
#    'Flighted',
#    'PSP',
#    'JFK',
#    'notification',
#    'ability',
#    'rebook',
#    'disappointed',
#    'expect',
#    'well'],
#   'negative'),
#  (['VirginAmerica',
#    'love',
#    'guy',
#    "'s",
#    'song',
#    "'re",
#    'dance',
#    'high',
#    'school',
#    'dance',
#    'revue'],
#   'positive'),
#  (['VirginAmerica', 'website', "'m", 'try', 'check'], 'negative'),
#  (['VirginAmerica',
#    'do',
#    'Thank',
#    'quick',
#    'response',
#    'apparently',
#    'faster',
#    'sit',
#    'hold'],
#   'positive'),
#  (['VirginAmerica',
#    'nervous',
#    'flight',
#    'DC',
#    'LAX',
#    'get',
#    'Cancelled',
#    'Flightled',
#    'tomorrow',
#    'sent',
#    'DM',
#    'help'],
#   'neutral'),
#  (['VirginAmerica',
#    'cool',
#    'picture',
#    'another',
#    'VirginAmerica',
#    'plane',
#    'wing',
#    'site',
#    'http',
#    '//t.co/5B2agFd8c4'],
#   'positive'),
#  (['VirginAmerica', 'Keep', 'great', 'work'], 'positive'),
#  (['VirginAmerica',
#    'goodness',
#    'people',
#    'love',
#    'field',
#    'amaze',
#    'pressure',
#    '❤️from',
#    'Texas',
#    'beatstheothers',
#    'crisis',
#    'Please',
#    'fly',
#    'NY'],
#   'positive'),
#  (['VirginAmerica',
#    'Thanks',
#    'great',
#    'flight',
#    'LA',
#    'Boston',
#    'Pilots',
#    'great',
#    'job',
#    'land',
#    'snow',
#    'go',
#    'back',
#    'LA',
#    'seriously'],
#   'positive'),
#  (['VirginAmerica',
#    'please',
#    'get',
#    'new',
#    'york',
#    'area',
#    'monday',
#    'afternoon'],
#   'neutral'),
#  (['VirginAmerica', 'Thanks', 'much', 'awesome', 'support', 'guy', 'rock'],
#   'positive'),
#  (['VirginAmerica',
#    'seat',
#    'Row',
#    '8',
#    "n't",
#    'recline',
#    'mention',
#    'website',
#    'soreback'],
#   'negative'),
#  (['VirginAmerica',
#    'flight',
#    '404',
#    'delayed',
#    '2',
#    'hour',
#    'LA',
#    'due',
#    'mechanical',
#    'problem',
#    'Handle',
#    'like',
#    'pro',
#    'could',
#    'toss',
#    'u',
#    'free',
#    'drink'],
#   'negative'),
#  (['VirginAmerica',
#    'Cancelled',
#    'Flight',
#    'flight',
#    'today',
#    'precipitation',
#    'scar',
#    '❄️❄️❄️'],
#   'negative'),
#  (['VirginAmerica',
#    'twitter',
#    'team',
#    'guy',
#    'kill',
#    'reschedule',
#    'asap',
#    'thank'],
#   'positive'),
#  (['VirginAmerica',
#    'guy',
#    'charge',
#    '100',
#    'reschedule',
#    'flight',
#    'Cancelled',
#    'Flighted',
#    'refuse',
#    'refund',
#    "'s",
#    'deal'],
#   'negative'),
#  (['VirginAmerica',
#    '’',
#    'access',
#    'website',
#    'Safari',
#    'iPhone',
#    '6',
#    'Seems',
#    'work',
#    'Mac',
#    'iPad',
#    'Need',
#    'iPhone',
#    'add',
#    'Passbook'],
#   'negative'),
#  (['VirginAmerica',
#    'iPad',
#    'iPhone',
#    'click',
#    'CHECKIN',
#    'link',
#    'email',
#    'receive',
#    '24hrs',
#    'flight'],
#   'neutral'),
#  (['VirginAmerica',
#    'mobile',
#    'site',
#    'broken',
#    'show',
#    "''",
#    'header.elevateUser.numOfPointsAvailable',
#    '||',
#    '0',
#    'number',
#    'Points',
#    "''",
#    'wo',
#    "n't",
#    'let',
#    'checkin'],
#   'negative'),
#  (['VirginAmerica',
#    'really',
#    'look',
#    'forward',
#    'flight',
#    'let',
#    'know',
#    'reschedule',
#    'diehardvirgin'],
#   'negative'),
#  (['VirginAmerica',
#    'Cancelled',
#    'Flight',
#    'flight',
#    'VX413',
#    'One',
#    'sec',
#    'delayed',
#    'airport',
#    'next',
#    'Cancelled',
#    'Flightled',
#    'Gon',
#    'na',
#    'email',
#    'call',
#    'reschedule'],
#   'negative'),
#  (['VirginAmerica', 'problem', 'link', 'email', 'check-in', 'thanks'],
#   'negative'),
#  (['VirginAmerica',
#    'change',
#    'another',
#    'airline',
#    'get',
#    'DC',
#    'today',
#    '...',
#    'united',
#    'able',
#    'land',
#    'DC',
#    'Cost',
#    '800',
#    '...',
#    'ugh'],
#   'negative'),
#  (['VirginAmerica',
#    'look',
#    'forward',
#    'first',
#    'flight',
#    'today',
#    'Cancelled',
#    'Flightled',
#    'along',
#    'subsequent',
#    'one',
#    '...'],
#   'negative'),
#  (['VirginAmerica',
#    'put',
#    'great',
#    'deal',
#    'PDX',
#    'LAS',
#    'LAS',
#    'PDX',
#    'show',
#    'love',
#    'http',
#    '//t.co/enIQg0buzj'],
#   'positive'),
#  (['VirginAmerica',
#    'wish',
#    'afford',
#    'fly',
#    'next',
#    'Friday',
#    'go',
#    'back',
#    'home',
#    '..',
#    'love',
#    'everything',
#    'airline'],
#   'positive'),
#  (['VirginAmerica',
#    'gon',
#    'na',
#    'deal',
#    'Dallas',
#    'DC',
#    'deal',
#    'DC',
#    'Dallas',
#    'sad'],
#   'negative'),
#  (['VirginAmerica', '’', 'bug', 'report', 'guy'], 'neutral'),
#  (['VirginAmerica', 'hold', 'time', 'call', 'center', 'bit', 'much'],
#   'negative'),
#  (['VirginAmerica', 'Like', 'http', '//t.co/VPqEm31XUQ'], 'positive'),
#  (['VirginAmerica', 'Site', 'help'], 'negative'),
#  (['VirginAmerica',
#    'best',
#    'flight',
#    'attendant',
#    'ever',
#    'http',
#    '//t.co/PxdEL1nq3l'],
#   'positive'),
#  (['Awesome',
#    'RT',
#    'VirginAmerica',
#    'Watch',
#    'nominate',
#    'film',
#    '35,000',
#    'foot',
#    'MeetTheFleet',
#    'Oscars',
#    'http',
#    '//t.co/DnStITRzWy'],
#   'positive'),
#  (['VirginAmerica', 'thanks', 'much'], 'positive'),
#  (['VirginAmerica',
#    'Trying',
#    'reset',
#    'password',
#    'email',
#    'never',
#    'arrives',
#    'Help'],
#   'negative'),
#  (['VirginAmerica',
#    'airline',
#    'base',
#    'Silicon',
#    'Valley',
#    'disruption',
#    'FCmostinnovative',
#    'incubator',
#    'FastCompany',
#    "'s",
#    'http',
#    '//t.co/wU3LbCNcr9'],
#   'positive'),
#  (['VirginAmerica', 'nicely', 'do', '👏'], 'positive'),
#  (['VirginAmerica',
#    '’',
#    'look',
#    'forward',
#    'watch',
#    'Oscars',
#    'flight',
#    'home',
#    'tomorrow',
#    'might',
#    'even',
#    'get',
#    'something',
#    'bubbly',
#    'drink'],
#   'positive'),
#  (['VirginAmerica',
#    'reason',
#    'delay',
#    'departure',
#    'VX',
#    '413',
#    'JFK',
#    'afternoon'],
#   'negative'),
#  (['VirginAmerica',
#    'today',
#    'flight',
#    'Palm',
#    'Springs',
#    'Ca',
#    'JFK',
#    'NY',
#    'Cancelled',
#    'Flightled'],
#   'negative'),
#  (['VirginAmerica',
#    'hahaha',
#    '😂',
#    'VirginAmerica',
#    'GUYS',
#    'AMAZING',
#    'LOVE',
#    'GUYS',
#    '💗'],
#   'positive'),
#  (['VirginAmerica', 'sound', 'like', 'fun'], 'positive'),
#  (['VirginAmerica', 'update', 'flight', '413', 'Jfk', 'gt', 'Lax'], 'neutral'),
#  (['virginamerica', 'spruce', 'moose'], 'neutral'),
#  (['VirginAmerica',
#    'CSS',
#    'site',
#    '404',
#    'right',
#    'please',
#    'fix',
#    'Site',
#    'unusable'],
#   'negative'),
#  (['VirginAmerica',
#    "'re",
#    'flight',
#    '910',
#    'Vegas',
#    'Boston',
#    'today',
#    'checked',
#    'online',
#    'bag',
#    'count',
#    "n't",
#    'register',
#    'fix',
#    'somehow'],
#   'negative'),
#  (['VirginAmerica', 'classiq', 'luv', 'Virgin', 'America', 'Greetingz'],
#   'positive'),
#  (['VirginAmerica',
#    'Hi',
#    "'m",
#    'try',
#    'check-in',
#    'website',
#    'work',
#    'try',
#    '3',
#    'different',
#    'browser',
#    'problem',
#    'continue'],
#   'negative'),
#  (['VirginAmerica',
#    'Thanks',
#    'great',
#    'customer',
#    'service',
#    'today',
#    'amp',
#    'help',
#    'get',
#    'travel',
#    'sort'],
#   'positive'),
#  (['VirginAmerica',
#    'thanks',
#    'guy',
#    'Sweet',
#    'route',
#    'Rockies',
#    'airplanemodewason'],
#   'positive'),
#  (['VirginAmerica',
#    'love',
#    '90',
#    'music',
#    'blasting',
#    'gate',
#    'Boston',
#    'wait',
#    'flight',
#    'SanFrancisco',
#    'could',
#    'get',
#    'iced',
#    'coffee'],
#   'positive'),
#  (['VirginAmerica',
#    'passenger',
#    '7D',
#    'Flt',
#    '338',
#    'assault',
#    "n't",
#    'flown',
#    'trust',
#    "'s",
#    'ban',
#    'Crew',
#    'file',
#    'report',
#    'FAANews'],
#   'negative'),
#  (['VirginAmerica',
#    'current',
#    'bug',
#    'website',
#    'show',
#    '‘',
#    'select',
#    'departure',
#    'city',
#    '’',
#    'select',
#    'destination',
#    'city',
#    'http',
#    '//t.co/SLLYIBE2vQ'],
#   'negative'),
#  (['VirginAmerica',
#    'luggage',
#    'severely',
#    'dented/missing',
#    'wheel',
#    'come',
#    'baggage',
#    'claim',
#    'SAN',
#    'Luggage',
#    'agent',
#    'Miranda',
#    'think',
#    "n't",
#    'help'],
#   'negative'),
#  (['VirginAmerica',
#    'thank',
#    'easy',
#    'itinerary',
#    'shift',
#    'impend',
#    'weather',
#    'Quick',
#    'painless',
#    'amp',
#    'free'],
#   'positive'),
#  (['VirginAmerica',
#    "'d",
#    'love',
#    'see',
#    'girl',
#    'inspire',
#    'become',
#    'pilot',
#    'RT',
#    'free',
#    'WOAW',
#    'event',
#    'March',
#    '2-8',
#    'ABQ',
#    'http',
#    '//t.co/rfXlV1kGDh'],
#   'neutral'),
#  (['VirginAmerica',
#    'Thanks',
#    'Good',
#    'time',
#    'back',
#    'Vodkatonics',
#    'entire',
#    'flight🍸',
#    'sfo'],
#   'positive'),
#  (['VirginAmerica',
#    'beat',
#    'expectation',
#    'share',
#    'take',
#    'Santa',
#    'Cruz',
#    'Sentinel',
#    'http',
#    '//t.co/qm9dQbai6G'],
#   'neutral'),
#  (['VirginAmerica', 'plan', 'start', 'fly', 'direct', 'DAL', 'LAS'],
#   'neutral'),
#  (['VirginAmerica',
#    'BIG',
#    'Love/gratitude.mpower',
#    'w/',
#    'http',
#    '//t.co/1AGR9knCpf',
#    'weRin',
#    'OSCARS2105',
#    'VIPswagbags',
#    'AvalonHollywood',
#    'http',
#    '//t.co/ybMbGs0dHn'],
#   'neutral'),
#  (['VirginAmerica',
#    "'re",
#    'great',
#    'job',
#    'add',
#    'little',
#    'luxuries/aesthetics',
#    'improve',
#    'air',
#    'travel',
#    'experience',
#    'Thank',
#    'Keep'],
#   'positive'),
#  (['VirginAmerica',
#    'request',
#    'window',
#    'seat',
#    'confirm',
#    'window',
#    'get',
#    'stuck',
#    'middle',
#    'seat',
#    'good',
#    'way',
#    'treat',
#    'silver',
#    'member😒'],
#   'negative'),
#  (['VirginAmerica', 'Grand', 'Budapest', 'Hotel', 'OscarsCountdown'],
#   'neutral'),
#  (['VirginAmerica', 'miss', 'NewsVP', 'Next', 'trip', '407'], 'neutral'),
#  (['VirginAmerica',
#    'wtf',
#    'paid',
#    'direct',
#    'flight',
#    'purpose',
#    'stop',
#    'fuel',
#    'exhaust',
#    'frequent',
#    'flier',
#    'nothing',
#    'inconvenience'],
#   'negative'),
#  (['VirginAmerica', 'something', 'wrong', 'website', 'Safari', 'iPhone'],
#   'negative'),
#  (['VirginAmerica',
#    'thanks',
#    'gate',
#    'check',
#    'baggage',
#    'full',
#    'flight',
#    'dfw-lax',
#    '883',
#    'give',
#    'early',
#    'boarding',
#    'sweet'],
#   'positive'),
#  (['VirginAmerica', 'Already', 'checked', 'page', 'expire', 'X'], 'negative'),
#  (['VirginAmerica',
#    'Boo',
#    'refund',
#    'seat',
#    'upgrade',
#    'fee',
#    'want',
#    'buy',
#    'first',
#    'place'],
#   'negative'),
#  (['VirginAmerica',
#    'share',
#    'rise',
#    'Q4',
#    'financial',
#    'result',
#    'USA',
#    'TODAY',
#    'http',
#    '//t.co/lFS4PEFE6y'],
#   'neutral'),
#  (['VirginAmerica',
#    'Adds',
#    'Pillows',
#    'Instead',
#    'Lie-Flat',
#    'Seats',
#    'First',
#    'Class',
#    'Arms',
#    'Race',
#    'http',
#    '//t.co/rGYwJBbhm4'],
#   'neutral'),
#  (['VirginAmerica', 'see'], 'positive'),
#  (['VirginAmerica', 'way', 'take', 'advantage', 'MayweatherPacquiao'],
#   'neutral'),
#  (['VirginAmerica',
#    'know',
#    "'m",
#    'fly',
#    'virgin',
#    'fight',
#    'MayweatherPacquiao'],
#   'neutral'),
#  (['VirginAmerica', 'inflight', 'team', 'make', 'experience', 'amaze'],
#   'positive'),
#  (['VirginAmerica',
#    'cutest',
#    'salt',
#    'pepper',
#    'shaker',
#    'ever',
#    'think',
#    'guy',
#    'ca',
#    "n't",
#    'get',
#    'well',
#    'http',
#    '//t.co/vC6Keulg2J'],
#   'positive'),
#  (['VirginAmerica',
#    'move',
#    'seat',
#    'notice',
#    '``',
#    'Better',
#    'seat',
#    "''",
#    'cabin',
#    'select',
#    'behind',
#    'row',
#    'selected👎',
#    'DISAPPOINTED'],
#   'negative'),
#  (['VirginAmerica',
#    'share',
#    '4Q',
#    'result',
#    'iol',
#    'http',
#    '//t.co/XZ6qeG3nef'],
#   'neutral'),
#  (['VirginAmerica', 'fav', 'airline'], 'positive'),
#  (['VirginAmerica', 'hot', 'female', 'pilot', 'Sweet', 'DCA', 'SFO'],
#   'positive'),
#  (['👍👍✈️✈️💗',
#    'guy',
#    'go',
#    'start',
#    'fly',
#    'Paris',
#    'VirginAmerica',
#    'LizaUtter',
#    "'re",
#    'welcome',
#    '”'],
#   'neutral'),
#  (['VirginAmerica',
#    'policy',
#    'fly',
#    'surgery',
#    'still',
#    'wait',
#    'answer',
#    'tell',
#    'doctor'],
#   'neutral'),
#  (['VirginAmerica',
#    'already',
#    'contact',
#    'Central',
#    'Baggage',
#    'amp',
#    'sent',
#    'DM',
#    'RenttheRunway',
#    'charge',
#    'dress',
#    'lose',
#    'suitcase',
#    'help'],
#   'negative'),
#  (['VirginAmerica', 'Thank'], 'positive'),
#  (['VirginAmerica',
#    'anything',
#    'go',
#    'website',
#    "'ve",
#    'get',
#    'lot',
#    'error',
#    'past',
#    '30',
#    'minute'],
#   'negative'),
#  (['VirginAmerica',
#    'think',
#    'left',
#    'something',
#    'plane',
#    'yesterday',
#    'call',
#    '...',
#    'ah'],
#   'neutral'),
#  (['VirginAmerica', 'need', 'follow', 'back', 'order', 'DM'], 'neutral'),
#  (['VirginAmerica', 'Need', 'start', 'fly', 'KCIAirport', '😊😀😃😄'], 'neutral'),
#  (['VirginAmerica',
#    'told',
#    'check',
#    'airline',
#    'regulation',
#    'first',
#    'contact'],
#   'neutral'),
#  (['VirginAmerica',
#    'VirginAtlantic',
#    'checked',
#    'flight',
#    'SFO',
#    'LAX',
#    'amp',
#    'told',
#    'Atlantic',
#    'Flying',
#    'Club',
#    'Gold',
#    'get',
#    'benefit'],
#   'negative'),
#  (['VirginAmerica',
#    'husband',
#    'order',
#    'three',
#    'drink',
#    'via',
#    'screen',
#    'never',
#    'come',
#    'Awesome'],
#   'negative'),
#  (['VirginAmerica',
#    'soooo',
#    'guy',
#    'go',
#    'leave',
#    'seatbelt',
#    'light',
#    'flight',
#    'barely',
#    'call',
#    'turbulence'],
#   'negative'),
#  (['VirginAmerica', 'policy', 'fly', 'surgery'], 'neutral'),
#  (['VirginAmerica',
#    'post',
#    'second',
#    'consecutive',
#    'full-year',
#    'net',
#    'profit',
#    'ATWOnline',
#    'http',
#    '//t.co/tvB5zbzVhg'],
#   'neutral'),
#  (['VirginAmerica',
#    'Funny',
#    'story',
#    'website',
#    'broken',
#    'miss',
#    'javascript',
#    'stylesheets',
#    'checkin',
#    'process',
#    'dislike'],
#   'negative'),
#  (['VirginAmerica', 'would', 'love', 'virgin', 'like', 'GoPro'], 'positive'),
#  (['VirginAmerica',
#    'Results',
#    'Handily',
#    'Exceed',
#    'Forecasts',
#    'NYTimes',
#    'http',
#    '//t.co/gonmRwEM6I'],
#   'neutral'),
#  (['VirginAmerica',
#    'apply',
#    'position',
#    'flyLAXairport',
#    'wonder',
#    'guy',
#    'receive',
#    'application'],
#   'neutral'),
#  (['VirginAmerica',
#    'achieves',
#    'second',
#    'year',
#    'profitability',
#    'despite',
#    'revenue',
#    'pressure',
#    '...',
#    'CAPA_Aviation',
#    'http',
#    '//t.co/zSuZTNAIJq'],
#   'neutral'),
#  (['VirginAmerica',
#    'give',
#    'positive',
#    'outlook',
#    'see',
#    'increase',
#    'competition',
#    'Reuters',
#    'http',
#    '//t.co/jEu7Od3eYJ'],
#   'neutral'),
#  (['VirginAmerica',
#    "'m",
#    'try',
#    'check',
#    '10:50AM',
#    'CT',
#    'flight',
#    'tmm',
#    'desktop',
#    'website',
#    "'s",
#    'work',
#    'sort',
#    'cache',
#    'bug',
#    'SOS'],
#   'negative'),
#  (['VirginAmerica',
#    'weather',
#    'delay',
#    'gt',
#    'next',
#    'week',
#    'JFK',
#    'BOS',
#    'DCA'],
#   'neutral'),
#  (['VirginAmerica', 'madbee95', 'check', 'website', 'go', 'airport'],
#   'neutral'),
#  (['VirginAmerica',
#    'guy',
#    'know',
#    'check-in',
#    'link',
#    'email',
#    'broken',
#    'http',
#    '//t.co/2npXB6oBMr'],
#   'negative'),
#  (['VirginAmerica',
#    'pilot',
#    'say',
#    'expect',
#    'choppy',
#    'land',
#    'NYC',
#    'due',
#    'gusty',
#    'wind',
#    'w/a',
#    'temperature',
#    '5',
#    'degree',
#    'amp',
#    'w/the',
#    'windchill',
#    '-8'],
#   'neutral'),
#  (['VirginAmerica',
#    'love',
#    'Ca',
#    "n't",
#    'wait',
#    'Monday',
#    "'s",
#    'return',
#    'flight',
#    '...',
#    'Mostly',
#    'watch',
#    'inflight',
#    'safety',
#    'video',
#    'sorrynotsorry'],
#   'positive'),
#  (['VirginAmerica',
#    'lose',
#    'luggage',
#    '4',
#    'day',
#    'ago',
#    'flight',
#    'VX',
#    '112',
#    'LAX',
#    'IAD',
#    'amp',
#    "'m",
#    'call',
#    'every',
#    'day',
#    'response.Please',
#    'give',
#    'back',
#    'stuff'],
#   'negative'),
#  (['VirginAmerica',
#    'Flight',
#    'Booking',
#    'Problems',
#    'section',
#    'website',
#    'seem',
#    'broken',
#    'Chrome',
#    'Might',
#    'wan',
#    'na',
#    'look'],
#   'negative'),
#  (['VirginAmerica',
#    'Hi',
#    'want',
#    'see',
#    'new',
#    'route',
#    'plan',
#    'year',
#    'Newark',
#    'Love',
#    'fly',
#    'guy',
#    'hope'],
#   'positive'),
#  (['VirginAmerica', 'mean', 'Probably', 'inappropriate', 'board', '..', "'s"],
#   'positive'),
#  (['VirginAmerica', 'happy', 'spend', 'day', 'together', 'Let', "'s"],
#   'positive'),
#  (['VirginAmerica', 'save', 'sanity', 'right', 'http', '//t.co/ELtBOLjUl9'],
#   'neutral'),
#  (['VirginAmerica', 'miss', 'flight', 'standby', 'work'], 'neutral'),
#  (['VirginAmerica', 'understand', 'help', 'Thx', 'Comps'], 'positive'),
#  (['VirginAmerica',
#    'brought',
#    'way',
#    'across',
#    'country',
#    'today',
#    'see',
#    'http',
#    '//t.co/TKaUyGcPmS'],
#   'neutral'),
#  (['VirginAmerica', 'thank', 'absolutely', '😎'], 'positive'),
#  (['virginamerica',
#    'Looks',
#    'like',
#    'broken',
#    'link',
#    'asset',
#    'http',
#    '//t.co/OArDjjGrrD'],
#   'negative'),
#  (['VirginAmerica',
#    'ready',
#    'Let',
#    "'s",
#    'say',
#    'together',
#    '..',
#    "'Noooo",
#    'turbulence',
#    'today',
#    '😘'],
#   'neutral'),
#  (['virginamerica',
#    'manage',
#    'itinerary',
#    'section',
#    'website',
#    'seem',
#    'broken',
#    'http',
#    '//t.co/2pUJvCElNg'],
#   'negative'),
#  (['VirginAmerica',
#    'ca',
#    "n't",
#    'check',
#    'site',
#    'look',
#    'like',
#    'every',
#    'time',
#    'load',
#    'http',
#    '//t.co/kAcY2AwDbW'],
#   'negative'),
#  (['VirginAmerica',
#    'u',
#    'help',
#    '👸',
#    'FreyaBevan_Fund',
#    'need',
#    'urgent',
#    'treatment',
#    'in🇺🇸2y',
#    'old',
#    'battling',
#    'cancer',
#    'could',
#    'u',
#    'help',
#    'flight',
#    '💗',
#    'freyasfund'],
#   'neutral'),
#  (['virginamerica',
#    'may',
#    'start',
#    'service',
#    'Hawaii',
#    'SanFrancisco',
#    'year',
#    'http',
#    '//t.co/yPo7nYpRZl',
#    'biztravel'],
#   'neutral'),
#  (['virginAmerica',
#    'carrier',
#    'less',
#    'half',
#    'price',
#    'round',
#    'trip',
#    'fare',
#    'stun',
#    'http',
#    '//t.co/UKdjjijroW'],
#   'negative'),
#  (['VirginAmerica',
#    'WTF',
#    'happen',
#    'PDX',
#    'Late',
#    'Flight',
#    'March',
#    'one',
#    'way',
#    'SFO',
#    '550'],
#   'negative'),
#  (['VirginAmerica', 'add', 'DTW', "'m", 'sell'], 'neutral'),
#  (['VirginAmerica', 'free', 'drink', 'flight', 'back', 'free', 'promo'],
#   'positive'),
#  (['VirginAmerica', 'SSal', 'thanks'], 'positive'),
#  (['VirginAmerica', 'momma', 'make', '😁😁😁'], 'neutral'),
#  (['VirginAmerica',
#    'please',
#    'contact',
#    'portfolio',
#    'left',
#    'flight',
#    'VX',
#    '27',
#    'JFK',
#    'SFO',
#    'tonite',
#    'seat',
#    '7AM',
#    'Need',
#    'return',
#    'Call',
#    '914-329-0185'],
#   'neutral'),
#  (['VirginAmerica',
#    'help',
#    'Flight',
#    '27',
#    'JKF',
# ...
#    'YVR',
#    'Flying',
#    'UA',
#    'tomorrow'],
#   'neutral'),
#  (['united', 'Mexico', 'international', 'u'], 'neutral'),
#  (['united',
#    'divert',
#    'miss',
#    'connect',
#    'flight',
#    'told',
#    'bag',
#    "'s",
#    'way',
#    'MSY',
#    'people',
#    'care'],
#   'negative'),
#  (['united',
#    'Male',
#    'agnt',
#    'LAS',
#    'threatens',
#    'Canadian',
#    'cust',
#    'cust',
#    'take',
#    'pic',
#    'gate',
#    'agent',
#    'announce',
#    'ca',
#    "n't",
#    'help',
#    'rebook',
#    'friendlyskies'],
#   'negative'),
#  (['united',
#    'Apollochplayers',
#    'want',
#    'go',
#    'home',
#    'tonight',
#    'Cancelled',
#    'Flight',
#    'last',
#    'leg',
#    'reserv',
#    'w/out',
#    'permission',
#    'PH6RPS'],
#   'negative'),
#  (['united',
#    'Stressed',
#    'rude',
#    'agent',
#    'Overwhelmed',
#    'delyd',
#    'flight',
#    'LAS-DEN',
#    '1657',
#    'Yelling',
#    'several',
#    'people',
#    'pretty',
#    'friendlyskies'],
#   'negative'),
#  (['united',
#    'land',
#    'Boston',
#    '9',
#    'last',
#    'night',
#    '15',
#    'hour',
#    'travel',
#    'rough',
#    'tho'],
#   'negative'),
#  (['united',
#    'FAIL',
#    'Cancelled',
#    'Flightled',
#    'flight',
#    'frm',
#    'GJT',
#    'use',
#    'reserv',
#    'home',
#    'IAH',
#    'SEA',
#    'reFlight',
#    'Booking',
#    'Problems',
#    'w/out',
#    'PERMISSION',
#    'PH6RPS'],
#   'negative'),
#  (['sent',
#    'thank',
#    'u',
#    'RT',
#    'united',
#    'goodenufmother',
#    'Please',
#    'DM',
#    'confirmation',
#    'number',
#    'reFlight',
#    'Booking',
#    'Problems',
#    'need',
#    'Thank',
#    '^EY'],
#   'neutral'),
#  (['united',
#    'make',
#    'fly',
#    'list',
#    'airline',
#    'wait',
#    'connector',
#    'Late',
#    'Flight',
#    'Stuck',
#    'IAH'],
#   'negative'),
#  (['United',
#    '’',
#    'deal',
#    'u',
#    'provide',
#    'voucher',
#    'overnight',
#    'cozy',
#    'floor',
#    'OHare',
#    'gross',
#    'HelpMePlease',
#    'AnyoneThere'],
#   'neutral'),
#  (['united',
#    'also',
#    'mere',
#    'fact',
#    'go',
#    'online',
#    'issue',
#    'statement',
#    'vice',
#    'call',
#    'talk',
#    'directly',
#    'one',
#    'good',
#    'example'],
#   'negative'),
#  (['united', 'thank', 'flew', 'Newark', 'Vail/Eagle'], 'positive'),
#  (['united', 'weekend', 'deal', 'company', 'would', 'say', 'otherwise'],
#   'negative'),
#  (['United',
#    'http',
#    '//t.co/5hpSqVRjK8',
#    'flight',
#    'go',
#    'get',
#    'plane',
#    'BusinessTravel',
#    'goodenoughmother'],
#   'negative'),
#  (['united',
#    'proper',
#    'response',
#    'sorry',
#    'wait',
#    'flight',
#    'look',
#    'issue',
#    "'s",
#    'Delta',
#    'would',
#    'handle'],
#   'negative'),
#  (['united',
#    'customer',
#    'service',
#    'terrible',
#    'Stood',
#    'inline',
#    '3',
#    'hour',
#    'flight',
#    '4',
#    'hour',
#    'Late',
#    'Flightr',
#    'still',
#    'bag',
#    'disgutedindenver'],
#   'negative'),
#  (['united',
#    'please',
#    'upload',
#    'March',
#    'on-demand',
#    'entertainment',
#    'listing',
#    'website',
#    '✈️'],
#   'neutral'),
#  (['united', 'inadequate', 'accident'], 'negative'),
#  (['united',
#    'reebok',
#    'rockinwellness',
#    'Denver',
#    'International',
#    'Airport',
#    'http',
#    '//t.co/tKVmHBkeC3'],
#   'positive'),
#  (['united', 'Thank', 'respond', 'quickly', 'helpful', 'tool', 'dustyob'],
#   'positive'),
#  (['united',
#    'boarding',
#    'time',
#    'show',
#    '35',
#    'min',
#    'gate',
#    'agent',
#    'start',
#    '45.',
#    'show',
#    '4:00',
#    'check',
#    'bag',
#    'http',
#    '//t.co/zCBJyo6lsN'],
#   'negative'),
#  (['united',
#    'Agent',
#    'LAS',
#    'let',
#    '20',
#    'customer',
#    'know',
#    'ca',
#    "n't",
#    'help',
#    'rebook',
#    'delayed',
#    'flight',
#    'DEN',
#    'unfriendlyskies',
#    'http',
#    '//t.co/QuzVmK2rTR'],
#   'negative'),
#  (['united',
#    'empathizes',
#    'w/',
#    'disappointment',
#    '1stClass',
#    'flight',
#    'w/nonworking',
#    'entertainmnt',
#    'worth',
#    '50',
#    'UnFriendlySkies',
#    'http',
#    '//t.co/lOecO4gmvd'],
#   'negative'),
#  (['united', '...', "n't", 'work', '...'], 'negative'),
#  (['united',
#    'see',
#    'message',
#    'today',
#    'mcdonnell',
#    'Douglas',
#    'dc',
#    '10',
#    'model',
#    'hear',
#    'read',
#    'Goodnight'],
#   'neutral'),
#  (['united',
#    'search',
#    'mileage',
#    'ticket',
#    'BOM',
#    'could',
#    "n't",
#    'find',
#    'single',
#    'one',
#    'saver',
#    'award',
#    'see',
#    'play',
#    'Earn',
#    'mile',
#    'ca',
#    "n't",
#    'use'],
#   'negative'),
#  (['united',
#    'flight',
#    'arrives',
#    '30',
#    'minute',
#    'early',
#    'wait',
#    'hour',
#    'bag'],
#   'negative'),
#  (['united',
#    "'s",
#    'issue',
#    'fact',
#    'one',
#    'even',
#    'call',
#    'despite',
#    'promise',
#    'confirm',
#    'bag',
#    "'s",
#    'location'],
#   'negative'),
#  (['united',
#    "'s",
#    'girl',
#    'get',
#    'ta',
#    'get',
#    'flight',
#    'name',
#    'change',
#    'bought',
#    'one',
#    'mean',
#    'ex',
#    'boyfriend',
#    'need',
#    'girl',
#    "'s",
#    'trip',
#    'stat'],
#   'neutral'),
#  (['united',
#    'thank',
#    'sign',
#    'notification',
#    'shall',
#    'watch',
#    'wait',
#    '❄️❄️'],
#   'neutral'),
#  (['united',
#    'still',
#    'wait',
#    'hear',
#    'back',
#    'wallet',
#    'steal',
#    'one',
#    'plane',
#    'would',
#    'appreciate',
#    'resolution'],
#   'negative'),
#  (['united',
#    'would',
#    'love',
#    'someone',
#    'could',
#    'get',
#    'back',
#    'Austin',
#    'tonight',
#    'wish',
#    'wait',
#    'til',
#    'tomorrow',
#    'morning'],
#   'neutral'),
#  (['united',
#    'flysaa',
#    'lose',
#    'baggage…',
#    'heard',
#    'different',
#    'thing',
#    'different',
#    'employee',
#    'united',
#    'flysaa',
#    'say',
#    'nothing'],
#   'negative'),
#  (['united',
#    'c',
#    'think',
#    'mile',
#    'repair',
#    'damage',
#    'do',
#    'interest',
#    'travel',
#    'united',
#    'exp',
#    'bad',
#    'flight',
#    'ever'],
#   'negative'),
#  (['united',
#    '0530',
#    'flight',
#    'DFW',
#    'Tuesday',
#    'far',
#    'advance',
#    'give',
#    'notice',
#    'Cancelled',
#    'Flightled'],
#   'neutral'),
#  (['united',
#    'sign',
#    'notification',
#    'first',
#    'trip',
#    'update',
#    'sure',
#    'happen'],
#   'negative'),
#  (['united',
#    'Thank',
#    'Took',
#    'care',
#    'everything',
#    'make',
#    'right',
#    "'s",
#    'experience',
#    "'m",
#    'use',
#    'Opened',
#    'app',
#    'find',
#    'flight',
#    'change'],
#   'positive'),
#  (['united',
#    'line',
#    'response',
#    "'m",
#    'wait',
#    'tomorrow',
#    'morning',
#    'flight',
#    'overbooked'],
#   'negative'),
#  (['united',
#    'take',
#    'exact',
#    'aircraft',
#    'LAX',
#    '3',
#    'day',
#    'ago',
#    'fit',
#    'problem',
#    'agent',
#    'today',
#    'told',
#    'nonsense',
#    'policy',
#    'change'],
#   'negative'),
#  (['united',
#    'helpful',
#    'agent',
#    'Club',
#    'help',
#    'baggage',
#    'fee',
#    'night',
#    'life.stop',
#    'business',
#    'SilverAirways'],
#   'negative'),
#  (['United', 'never', 'heard', 'http', '//t.co/QDebyaHqfM'], 'negative'),
#  (['SouthwestAir',
#    "n't",
#    'charge',
#    'ticket',
#    'change',
#    'fee',
#    'incur',
#    'mysterious',
#    '``',
#    'cost',
#    "''",
#    'incur',
#    'united'],
#   'negative'),
#  (['united',
#    'Exhausted',
#    'amp',
#    'frustrate',
#    'Link',
#    'FB',
#    'post',
#    'abt',
#    'travel',
#    'issue',
#    'http',
#    '//t.co/LaRKC8vc4s'],
#   'negative'),
#  (['united',
#    'deny',
#    'get',
#    'plane',
#    'w/o',
#    'get',
#    'chance',
#    'prove',
#    'fit',
#    "'m",
#    'rookie',
#    'Read',
#    'bio'],
#   'negative'),
#  (['united',
#    "'s",
#    'exactly',
#    'point',
#    'fit',
#    "'m",
#    'premier',
#    'access',
#    'Boarding',
#    'group',
#    '2',
#    'return',
#    'ticket',
#    "'ve",
#    '15',
#    'yr'],
#   'positive'),
#  (['united',
#    "'ve",
#    'never',
#    'experienced',
#    'bad',
#    'customer',
#    'service',
#    'Placing',
#    'blame',
#    'codeshare',
#    'partner',
#    'assume',
#    'responsibility',
#    'unacceptable'],
#   'negative'),
#  (['united',
#    'currently',
#    'board',
#    'Check',
#    'terrible',
#    'Staff',
#    'rude',
#    'Expensive',
#    'luggage',
#    'thrown',
#    'around',
#    'etc'],
#   'negative'),
#  (['United',
#    'fuck',
#    'void',
#    'ticket',
#    'KEPT',
#    'MONEY',
#    'even',
#    'apology',
#    'never',
#    'fly',
#    'airline',
#    'UnitedAirlines'],
#   'negative'),
#  (['united',
#    'WORST',
#    'customer',
#    'svcs',
#    'Kevin',
#    'rep',
#    'call',
#    'center',
#    'must',
#    'investigate',
#    'baggage',
#    "'s",
#    'lose',
#    "'s",
#    'help',
#    'argument'],
#   'negative'),
#  (['united',
#    'sell',
#    'ticket',
#    'SilverAirways',
#    'http',
#    '//t.co/onhXHCO6bK',
#    'terrible',
#    'service',
#    'UA',
#    'staff',
#    'reach',
#    'Silver'],
#   'negative'),
#  (['united',
#    'get',
#    'demote',
#    'Gold',
#    'cuz',
#    'hubby',
#    'get',
#    '100',
#    'PQD',
#    'tho',
#    'enuf',
#    'spent',
#    '4',
#    'Golds.',
#    'spousal.discrimination/angry'],
#   'negative'),
#  (['united', 'Thank'], 'positive'),
#  (['united',
#    'direct',
#    'flight',
#    'Belfast',
#    'Intl',
#    'Newark',
#    'resume',
#    'winter',
#    'break',
#    'Thanks'],
#   'neutral'),
#  (['united',
#    'favorite',
#    'way',
#    'travel',
#    'Thank',
#    'http',
#    '//t.co/vGN2X1ckg0'],
#   'positive'),
#  (['united', 'yes', 'awful', 'weather', 'appear', 'get', 'home'], 'neutral'),
#  (['united',
#    'yes',
#    'lot',
#    'terrible',
#    'customer',
#    'service',
#    'Newark',
#    'despite',
#    'raise',
#    'complaint',
#    'ignore',
#    'hence',
#    'tweet'],
#   'negative'),
#  (['united', 'Lovely', 'new', 'plane', 'LGA', 'ORD', 'power', 'outlet'],
#   'negative'),
#  (['united',
#    'tweet',
#    'ID',
#    'number',
#    'wo',
#    "n't",
#    'reveal',
#    'home',
#    'address',
#    'anyone',
#    'web'],
#   'negative'),
#  (['united',
#    'file',
#    'delayed',
#    'bag',
#    'report',
#    'Saturday',
#    'flight',
#    'Cancelled',
#    'Flightled',
#    'never',
#    'go',
#    'anywhere'],
#   'negative'),
#  (['united', 'person', 'currently', 'bettween', 'gate', '71A', '73', 'LAX'],
#   'neutral'),
#  (['united',
#    'need',
#    'land',
#    'EWR',
#    'baggage',
#    'claim',
#    'file',
#    'sent',
#    'employee',
#    'droppeditoffyet'],
#   'negative'),
#  (['united',
#    'rarely',
#    'cease',
#    'amaze',
#    '...',
#    'bad',
#    'hope',
#    'last',
#    'time',
#    '``',
#    "''",
#    'fly'],
#   'negative'),
#  (['united', 'thank', 'quick', 'response', 'dm', 'follow', 'well'], 'neutral'),
#  (['united', 'iCloud', 'yet', '--', 'PLEASE', 'HELP', '917', '703', '1472'],
#   'negative'),
#  (['united',
#    'need',
#    'phone',
#    'number',
#    'baggage',
#    'claim',
#    'LAX',
#    'mom',
#    'left',
#    'phone',
#    'someone',
#    'call',
#    'say',
#    'would',
#    'put'],
#   'neutral'),
#  (['united', '...', 'response', 'back'], 'negative'),
#  (['united', 'atrocious', 'customer', 'service'], 'negative'),
#  (['United',
#    'honor',
#    'absurdly',
#    'low',
#    'mistake',
#    'fare',
#    'http',
#    '//t.co/2Z3Jv73IlW',
#    'vía',
#    'usatoday'],
#   'neutral'),
#  (['united',
#    'albanyairport',
#    'delayed',
#    'departure',
#    'check',
#    'bag',
#    'gate',
#    'claim',
#    'space',
#    'fill',
#    'walk',
#    'open',
#    'space',
#    'delay',
#    'poorcustomerservice'],
#   'negative'),
#  (['united',
#    'Cancelled',
#    'Flighted',
#    'flight',
#    'reason',
#    'amp',
#    'phone',
#    'HOUR',
#    'vacation'],
#   'negative'),
#  (['united',
#    'dfpietra',
#    "'S",
#    'response',
#    'Shaking',
#    'head',
#    'back',
#    'forth',
#    'tsk',
#    'better-from',
#    'customer',
#    'service',
#    'apology'],
#   'negative'),
#  (['united',
#    'thanks',
#    "'s",
#    '35K',
#    'mile',
#    'RTB',
#    'Europe',
#    'multiple',
#    'destination',
#    'could',
#    'stop',
#    'US',
#    'way/way',
#    'back-',
#    'mileage',
#    'diff'],
#   'neutral'),
#  (['united', 'course', 'bag', 'frustrate'], 'negative'),
#  (['united', 'bad', 'avoid', 'like', 'plague'], 'negative'),
#  (['united', 'bad', 'airline', 'world'], 'negative'),
#  (['united',
#    'someone',
#    'need',
#    'DM',
#    'resolve',
#    'correctly',
#    'Extremely',
#    'disappointed',
#    'service',
#    'receive',
#    'Terrible',
#    'management'],
#   'negative'),
#  (['united',
#    'Premier',
#    'Gold',
#    'desk',
#    'change',
#    'flight',
#    'Waives',
#    'fee',
#    'Gives',
#    'wrong',
#    'flight',
#    'Jana',
#    'Acosta',
#    'Salt',
#    'Lake',
#    'refuse',
#    'service',
#    'Angry'],
#   'negative'),
#  (['united',
#    'give',
#    'one',
#    'thing',
#    'consistent',
#    'unfortunately',
#    'consistent',
#    'job',
#    'well',
#    'AlwaysDelayedOnUnited'],
#   'negative'),
#  (['united', 'right', "'m", 'angry'], 'negative'),
#  (['united',
#    'first',
#    'time',
#    'fly',
#    'United',
#    'Also',
#    'last',
#    'time',
#    'terrible',
#    'back',
#    'VirginAtlantic',
#    'branson',
#    'virginatlantic',
#    'UnitedAirlines'],
#   'negative'),
#  (['united',
#    'use',
#    'commit',
#    'ContinentalAirlines',
#    'flyer',
#    'merger',
#    'remember',
#    'switch',
#    'SouthwestAir',
#    'CommunicationFail'],
#   'negative'),
#  (['united',
#    'least',
#    'could',
#    'offer',
#    'ticket',
#    'coach',
#    'instead',
#    'Cancelled',
#    'Flighting',
#    'reservation',
#    'glitch',
#    'notfair'],
#   'negative'),
#  (['united',
#    "'m",
#    'say',
#    'make',
#    'flight',
#    'poor/non-communication',
#    'unaccounted',
#    'lose',
#    'time',
#    'amp',
#    'lot',
#    'frustrate',
#    'flyer',
#    'stand',
#    'around'],
#   'negative'),
#  (['united', 'think', 'DM', 'would', 'well'], 'negative'),
#  (['United',
#    'gate',
#    'announcement',
#    'state',
#    'delay',
#    'due',
#    'maintenance',
#    'yet',
#    'app',
#    'say',
#    'Late',
#    'Flight',
#    'arrive',
#    'aircraft',
#    'tell',
#    'truth',
#    'unfriendly'],
#   'negative'),
#  (['united',
#    'easily',
#    'bad',
#    'company',
#    'ever',
#    'experienced',
#    'lose',
#    'someone',
#    "'s",
#    'personal',
#    'possession',
#    'amp',
#    'could',
#    "n't",
#    'care',
#    'less',
#    '....'],
#   'negative'),
#  (['united',
#    'app',
#    'show',
#    'arrive',
#    'aircraft',
#    'early',
#    'depart',
#    'flight',
#    'delayed',
#    'due',
#    'Late',
#    'Flight',
#    'arrive',
#    'aircraft',
#    'unfriendly'],
#   'negative'),
#  (['united',
#    'already',
#    'airport',
#    '12',
#    'hr',
#    'Late',
#    'Flightr',
#    'still',
#    'guy',
#    'really',
#    'kill',
#    'today',
#    'try',
#    'stay',
#    'positive',
#    '..'],
#   'negative'),
#  (['united',
#    'united',
#    "'s",
#    'service',
#    'level',
#    'reach',
#    'Etihad',
#    'let',
#    'realistically',
#    'Lufthansa',
#    'ill',
#    'consider'],
#   'negative'),
#  (['united',
#    'really',
#    'Someone',
#    'call',
#    'sick',
#    'someone',
#    'FORGOT',
#    'call',
#    'replacement',
#    'hour',
#    'Late',
#    'Flight',
#    'take',
#    'theworst'],
#   'negative'),
#  (['united',
#    'Asked',
#    'Flight',
#    'attendant',
#    'typical',
#    'compensation',
#    'would',
#    'amp',
#    'say',
#    'might',
#    'get',
#    'free',
#    'TV',
#    'Unacceptable'],
#   'negative'),
#  (['united', 'do'], 'neutral'),
#  (['united',
#    'Thank',
#    '^JH',
#    'appreciate',
#    'prompt',
#    'response',
#    '--',
#    'passenger'],
#   'neutral'),
#  (['united',
#    'disappointment',
#    'today',
#    'Simply',
#    'put',
#    'Rather',
#    'unpleased',
#    'thing',
#    'currently',
#    'Flight',
#    'delayed',
#    'cant',
#    'wait',
#    'get',
#    'home'],
#   'negative'),
#  (['united',
#    'round',
#    'trip',
#    'NON-English',
#    'speak',
#    'friend',
#    'strand',
#    'TWICE',
#    '12+',
#    'hour',
#    'time',
#    'staff',
#    'member',
#    'rude'],
#   'negative'),
#  (['united',
#    'found',
#    'group',
#    'people',
#    'actually',
#    'hate',
#    'people',
#    'ISIS',
#    'thats',
#    'right',
#    'United',
#    'Airlines'],
#   'negative'),
#  (['united',
#    'Nope',
#    'Walked',
#    'amp',
#    'ORF',
#    'terminal',
#    'amp',
#    'United',
#    'agent',
#    'found',
#    'Showed',
#    'last',
#    'minute',
#    'board',
#    'u',
#    'Many',
#    'panicked',
#    'people'],
#   'negative'),
#  (['united', 'thank'], 'positive'),
#  (['united',
#    'time',
#    'finally',
#    'get',
#    'Dallas',
#    'could',
#    'driven',
#    'less',
#    'frustration',
#    'cheaper'],
#   'negative'),
#  (['united',
#    "'m",
#    'try',
#    'get',
#    'final',
#    'destination',
#    'need',
#    'compensation',
#    '2hrs',
#    'personal',
#    'time',
#    'waste'],
#   'negative'),
#  (['united',
#    'guy',
#    'really',
#    'customer',
#    'service',
#    'clue.Could',
#    'spent',
#    'effort',
#    'clearing',
#    'bin',
#    'rollerboards',
#    'instead',
#    'art',
#    'project',
#    'mine'],
#   'negative'),
#  (['united', 'priority', 'Iove'], 'positive'),
#  (['united', 'Pleased', 'Premier', 'Platinum'], 'positive'),
#  ...]

# %%
documents[5]
# Out:
# (['VirginAmerica',
#   'seriously',
#   'would',
#   'pay',
#   '30',
#   'flight',
#   'seat',
#   "n't",
#   'play',
#   "'s",
#   'really',
#   'bad',
#   'thing',
#   'fly',
#   'VA'],
#  'negative')
